# %%
pip install --upgrade category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.1-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.10.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.13.5)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.1)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.1

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers)
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 75.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 100.6 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 99.4 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=ad71492ae47f1d5dff113fda54b38402bf6f2ef98fb31526bc30c128940576f3
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, huggingface-hub, transformers, sentence_transformers
# Successfully installed huggingface-hub-0.15.1 safetensors-0.3.1 sentence_transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.30.2

# %%
import pandas as pd
import numpy as np
#import spacy
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from nltk.tokenize import word_tokenize
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk import WordNetLemmatizer
nltk.download('wordnet')
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
import category_encoders as ce
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score
from sklearn.metrics import confusion_matrix,classification_report

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances
from sentence_transformers import SentenceTransformer

import warnings
warnings.simplefilter('ignore')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
news_df=pd.read_csv("flipitnews-data.csv")

# %%
news_df
# Out:
#            Category                                            Article
# 0        Technology  tv future in the hands of viewers with home th...
# 1          Business  worldcom boss  left books alone  former worldc...
# 2            Sports  tigers wary of farrell  gamble  leicester say ...
# 3            Sports  yeading face newcastle in fa cup premiership s...
# 4     Entertainment  ocean s twelve raids box office ocean s twelve...
# ...             ...                                                ...
# 2220       Business  cars pull down us retail figures us retail sal...
# 2221       Politics  kilroy unveils immigration policy ex-chatshow ...
# 2222  Entertainment  rem announce new glasgow concert us band rem h...
# 2223       Politics  how political squabbles snowball it s become c...
# 2224         Sports  souness delight at euro progress boss graeme s...
#
# [2225 rows x 2 columns]

# %%
print("Before pre processing, article look like this")
print()
news_df['Article'][0]
# Out:
# Before pre processing, article look like this
# 'tv future in the hands of viewers with home theatre systems  plasma high-definition tvs  and digital video recorders moving into the living room  the way people watch tv will be radically different in five years  time.  that is according to an expert panel which gathered at the annual consumer electronics show in las vegas to discuss how these new technologies will impact one of our favourite pastimes. with the us leading the trend  programmes and other content will be delivered to viewers via home networks  through cable  satellite  telecoms companies  and broadband service providers to front rooms and portable devices.  one of the most talked-about technologies of ces has been digital and personal video recorders (dvr and pvr). these set-top boxes  like the us s tivo and the uk s sky+ system  allow people to record  store  play  pause and forward wind tv programmes when they want.  essentially  the technology allows for much more personalised tv. they are also being built-in to high-definition tv sets  which are big business in japan and the us  but slower to take off in europe because of the lack of high-definition programming. not only can people forward wind through adverts  they can also forget about abiding by network and channel schedules  putting together their own a-la-carte entertainment. but some us networks and cable and satellite companies are worried about what it means for them in terms of advertising revenues as well as  brand identity  and viewer loyalty to channels. although the us leads in this technology at the moment  it is also a concern that is being raised in europe  particularly with the growing uptake of services like sky+.  what happens here today  we will see in nine months to a years  time in the uk   adam hume  the bbc broadcast s futurologist told the bbc news website. for the likes of the bbc  there are no issues of lost advertising revenue yet. it is a more pressing issue at the moment for commercial uk broadcasters  but brand loyalty is important for everyone.  we will be talking more about content brands rather than network brands   said tim hanlon  from brand communications firm starcom mediavest.  the reality is that with broadband connections  anybody can be the producer of content.  he added:  the challenge now is that it is hard to promote a programme with so much choice.   what this means  said stacey jolna  senior vice president of tv guide tv group  is that the way people find the content they want to watch has to be simplified for tv viewers. it means that networks  in us terms  or channels could take a leaf out of google s book and be the search engine of the future  instead of the scheduler to help people find what they want to watch. this kind of channel model might work for the younger ipod generation which is used to taking control of their gadgets and what they play on them. but it might not suit everyone  the panel recognised. older generations are more comfortable with familiar schedules and channel brands because they know what they are getting. they perhaps do not want so much of the choice put into their hands  mr hanlon suggested.  on the other end  you have the kids just out of diapers who are pushing buttons already - everything is possible and available to them   said mr hanlon.  ultimately  the consumer will tell the market they want.   of the 50 000 new gadgets and technologies being showcased at ces  many of them are about enhancing the tv-watching experience. high-definition tv sets are everywhere and many new models of lcd (liquid crystal display) tvs have been launched with dvr capability built into them  instead of being external boxes. one such example launched at the show is humax s 26-inch lcd tv with an 80-hour tivo dvr and dvd recorder. one of the us s biggest satellite tv companies  directtv  has even launched its own branded dvr at the show with 100-hours of recording capability  instant replay  and a search function. the set can pause and rewind tv for ...

# %% [markdown]
# ## Data Exploration

# %%
print("Shape of data is: ",news_df.shape)
# Out:
# Shape of data is:  (2225, 2)

# %%
news_df.describe()
# Out:
#        Category                                            Article
# count      2225                                               2225
# unique        5                                               2126
# top      Sports  kennedy questions trust of blair lib dem leade...
# freq        511                                                  2

# %%
news_df.isna().sum()
# Out:
# Category    0
# Article     0
# dtype: int64

# %% [markdown]
# Category-wise count of articles

# %%
plt.figure(figsize=(8,5))
fig=sns.countplot(x="Category",data=news_df)
fig.bar_label(fig.containers[0])
fig.set_xlabel("Category")
fig.set_ylabel("Number of articles")
plt.show()

# %% [markdown]
# ## Text pre-processing

# %%
stop_words=list(stopwords.words('english'))
def sentence_preprocess(sentence):
  sentence=re.sub('[^a-zA-z]',' ',sentence)   # remove non alphabets
  words=nltk.word_tokenize(sentence)          # tokenization
  cleaned_words=[word for word in words if not word in stop_words]    #removing stopwords
  lemma=WordNetLemmatizer()
  new_text=" ".join([lemma.lemmatize(word) for word in cleaned_words])  #lemmatization
  return new_text
news_df['Article']=news_df['Article'].apply(sentence_preprocess)

# %%
print("After pre processing, article look like this")
print()
news_df['Article'][0]
# Out:
# After pre processing, article look like this
# 'tv future hand viewer home theatre system plasma high definition tv digital video recorder moving living room way people watch tv radically different five year time according expert panel gathered annual consumer electronics show la vega discus new technology impact one favourite pastime u leading trend programme content delivered viewer via home network cable satellite telecom company broadband service provider front room portable device one talked technology ce digital personal video recorder dvr pvr set top box like u tivo uk sky system allow people record store play pause forward wind tv programme want essentially technology allows much personalised tv also built high definition tv set big business japan u slower take europe lack high definition programming people forward wind advert also forget abiding network channel schedule putting together la carte entertainment u network cable satellite company worried mean term advertising revenue well brand identity viewer loyalty channel although u lead technology moment also concern raised europe particularly growing uptake service like sky happens today see nine month year time uk adam hume bbc broadcast futurologist told bbc news website like bbc issue lost advertising revenue yet pressing issue moment commercial uk broadcaster brand loyalty important everyone talking content brand rather network brand said tim hanlon brand communication firm starcom mediavest reality broadband connection anybody producer content added challenge hard promote programme much choice mean said stacey jolna senior vice president tv guide tv group way people find content want watch simplified tv viewer mean network u term channel could take leaf google book search engine future instead scheduler help people find want watch kind channel model might work younger ipod generation used taking control gadget play might suit everyone panel recognised older generation comfortable familiar schedule channel brand know getting perhaps want much choice put hand mr hanlon suggested end kid diaper pushing button already everything possible available said mr hanlon ultimately consumer tell market want new gadget technology showcased ce many enhancing tv watching experience high definition tv set everywhere many new model lcd liquid crystal display tv launched dvr capability built instead external box one example launched show humax inch lcd tv hour tivo dvr dvd recorder one u biggest satellite tv company directtv even launched branded dvr show hour recording capability instant replay search function set pause rewind tv hour microsoft chief bill gate announced pre show keynote speech partnership tivo called tivotogo mean people play recorded programme window pc mobile device reflect increasing trend freeing multimedia people watch want want'

# %% [markdown]
# Ordinal Encoding

# %%
encode=ce.OrdinalEncoder(cols='Category')
news_df=encode.fit_transform(news_df)

# %%
news_df
# Out:
#       Category                                            Article
# 0            1  tv future hand viewer home theatre system plas...
# 1            2  worldcom bos left book alone former worldcom b...
# 2            3  tiger wary farrell gamble leicester say rushed...
# 3            3  yeading face newcastle fa cup premiership side...
# 4            4  ocean twelve raid box office ocean twelve crim...
# ...        ...                                                ...
# 2220         2  car pull u retail figure u retail sale fell ja...
# 2221         5  kilroy unveils immigration policy ex chatshow ...
# 2222         4  rem announce new glasgow concert u band rem an...
# 2223         5  political squabble snowball become commonplace...
# 2224         3  souness delight euro progress bos graeme soune...
#
# [2225 rows x 2 columns]

# %% [markdown]
# **Label encoded values**
# 1. Technology
# 2. Business
# 3. Sports
# 4. Entertainment
# 5. Politics

# %% [markdown]
# ## BERT

# %%
sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

document_embeddings = sbert_model.encode(news_df['Article'])

pairwise_similarities=cosine_similarity(document_embeddings)
pairwise_differences=euclidean_distances(document_embeddings)

# %%
y=np.array(news_df['Category'].values)
X_train_bert, X_test_bert, y_train, y_test= train_test_split(document_embeddings,y,test_size=0.3,shuffle=True,stratify=y,random_state=42)

print("Shape of train data is: ",X_train_bert.shape)
print("Shape of test data is: ",X_test_bert.shape)
# Out:
# Shape of train data is:  (1557, 768)
# Shape of test data is:  (668, 768)

# %%
dt=DecisionTreeClassifier()

#model training
y_pred_dt,y_pred_proba_dt=model_training(dt,X_train_bert, X_test_bert, y_train)

#model evaluation
evaluate_model(dt,y_pred_dt,y_pred_proba_dt,X_train_bert, X_test_bert, y_train,y_test)
# Out:
# Training accuracy:  1.0
# Testing accuracy:  0.74
# ROC AUC score:  0.835
# Precision score:  0.74
# Recall score:  0.74
# f1 score:  0.739

# %%
knn=KNeighborsClassifier(n_neighbors=3)

#model training
y_pred_knn,y_pred_proba_knn=model_training(knn,X_train_bert, X_test_bert, y_train)

#model evaluation
evaluate_model(knn,y_pred_knn,y_pred_proba_knn,X_train_bert, X_test_bert, y_train,y_test)
# Out:
# Training accuracy:  0.96
# Testing accuracy:  0.934
# ROC AUC score:  0.985
# Precision score:  0.934
# Recall score:  0.934
# f1 score:  0.934

# %%
rf=RandomForestClassifier()

#model training
y_pred_rf,y_pred_proba_rf=model_training(rf,X_train_bert, X_test_bert, y_train)

#model evaluation
evaluate_model(rf,y_pred_rf,y_pred_proba_rf,X_train_bert, X_test_bert, y_train,y_test)
# Out:
# Training accuracy:  1.0
# Testing accuracy:  0.939
# ROC AUC score:  0.992
# Precision score:  0.941
# Recall score:  0.939
# f1 score:  0.939

# %%
confusion=confusion_matrix(y_test,y_pred_knn)
plt.figure(figsize=(10,5))
sns.heatmap(confusion,annot=True,fmt='d',cbar=False,cmap='Blues')
plt.xlabel("Predicted label")
plt.ylabel("Actual label")
plt.show()

# %%
def most_similar(doc_id,similarity_matrix,matrix):
    print (f'Document: {news_df.iloc[doc_id]["Article"]}')
    print ('\n')
    print (f'Similar Documents using {matrix}:')
    if matrix=='Cosine Similarity':
        similar_ix=np.argsort(similarity_matrix[doc_id])[::-1]
    elif matrix=='Euclidean Distance':
        similar_ix=np.argsort(similarity_matrix[doc_id])
    for ix in similar_ix:
        if ix==doc_id:
            continue
        print('\n')
        print (f'Document: {[ix]}')
        print (f'{matrix} : {similarity_matrix[doc_id][ix]}')

# %%
pairwise_similarities=cosine_similarity(document_embeddings)
pairwise_differences=euclidean_distances(document_embeddings)

most_similar(0,pairwise_similarities,'Cosine Similarity')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# Document: [1455]
# Cosine Similarity : 0.6681653261184692
#
#
# Document: [42]
# Cosine Similarity : 0.668157160282135
#
#
# Document: [1924]
# Cosine Similarity : 0.6680857539176941
#
#
# Document: [1448]
# Cosine Similarity : 0.6680619120597839
#
#
# Document: [1485]
# Cosine Similarity : 0.6680582165718079
#
#
# Document: [1882]
# Cosine Similarity : 0.6680390238761902
#
#
# Document: [1418]
# Cosine Similarity : 0.6680386066436768
#
#
# Document: [470]
# Cosine Similarity : 0.6679995656013489
#
#
# Document: [1984]
# Cosine Similarity : 0.6679474115371704
#
#
# Document: [1125]
# Cosine Similarity : 0.6679161787033081
#
#
# Document: [596]
# Cosine Similarity : 0.6678744554519653
#
#
# Document: [1236]
# Cosine Similarity : 0.6678570508956909
#
#
# Document: [591]
# Cosine Similarity : 0.6675894856452942
#
#
# Document: [1888]
# Cosine Similarity : 0.6675307750701904
#
#
# Document: [1115]
# Cosine Similarity : 0.6674166917800903
#
#
# Document: [621]
# Cosine Similarity : 0.6673787832260132
#
#
# Document: [266]
# Cosine Similarity : 0.6673468351364136
#
#
# Document: [1697]
# Cosine Similarity : 0.6673324108123779
#
#
# Document: [1513]
# Cosine Similarity : 0.6672728061676025
#
#
# Document: [439]
# Cosine Similarity : 0.6672725677490234
#
#
# Document: [344]
# Cosine Similarity : 0.6671274304389954
#
#
# Document: [1358]
# Cosine Similarity : 0.6668521761894226
#
#
# Document: [1854]
# Cosine Similarity : 0.666793704032898
#
#
# Document: [2196]
# Cosine Similarity : 0.6667683124542236
#
#
# Document: [157]
# Cosine Similarity : 0.6666088104248047
#
#
# Document: [156]
# Cosine Similarity : 0.6665632128715515
#
#
# Document: [869]
# Cosine Similarity : 0.6665462255477905
#
#
# Document: [521]
# Cosine Similarity : 0.6665098071098328
#
#
# Document: [320]
# Cosine Similarity : 0.6664178371429443
#
#
# Document: [1873]
# Cosine Similarity : 0.6663856506347656
#
#
# Document: [1497]
# Cosine Similarity : 0.6663734912872314
#
#
# Document: [1588]
# Cosine Similarity : 0.6662555932998657
#
#
# Document: [1672]
# Cosine Similarity : 0.6661744713783264
#
#
# Document: [1008]
# Cosine Similarity : 0.6661697626113892
#
#
# Document: [774]
# Cosine Similarity : 0.6661204695701599
#
#
# Document: [1451]
# Cosine Similarity : 0.6661095023155212
#
#
# Document: [1457]
# Cosine Similarity : 0.6658320426940918
#
#
# Document: [12]
# Cosine Similarity : 0.6656484007835388
#
#
# Document: [195]
# Cosine Similarity : 0.6656466722488403
#
#
# Document: [1067]
# Cosine Similarity : 0.6655701398849487
#
#
# Document: [817]
# Cosine Similarity : 0.6655052304267883
#
#
# Document: [677]
# Cosine Similarity : 0.6654433608055115
#
#
# Document: [1642]
# Cosine Similarity : 0.6653031706809998
#
#
# Document: [274]
# Cosine Similarity : 0.6652935743331909
#
#
# Document: [2004]
# Cosine Similarity : 0.6651408076286316
#
#
# Document: [1915]
# Cosine Similarity : 0.6651105880737305
#
#
# Document: [1087]
# Cosine Similarity : 0.6651068329811096
#
#
# Document: [1624]
# Cosine Similarity : 0.664967954158783
#
#
# Document: [1383]
# Cosine Similarity : 0.6649374961853027
#
#
# Document: [221]
# Cosine Similarity : 0.6649150848388672
#
#
# Document: [2157]
# Cosine Similarity : 0.6649115085601807
#
#
# Document: [1907]
# Cosine Similarity : 0.6647546291351318
#
#
# Document: [15]
# Cosine Similarity : 0.6646121740341187
#
#
# Document: [1919]
# Cosine Similarity : 0.6646054983139038
#
#
# Document: [1689]
# Cosine Similarity : 0.6645685434341431
#
#
# Document: [2116]
# Cosine Similarity : 0.6645195484161377
#
#
# Document: [1938]
# Cosine Similarity : 0.6644822359085083
#
#
# Document: [888]
# Cosine Similarity : 0.6644653081893921
#
#
# Document: [1574]
# Cosine Similarity : 0.6644591689109802
#
#
# Document: [791]
# Cosine Similarity : 0.6644490361213684
#
#
# Document: [657]
# Cosine Similarity : 0.6644068360328674
#
#
# Document: [291]
# Cosine Similarity : 0.6644068360328674
#
#
# Document: [49]
# Cosine Similarity : 0.6642324328422546
#
#
# Document: [73]
# Cosine Similarity : 0.6642084121704102
#
#
# Document: [1712]
# Cosine Similarity : 0.6641144752502441
#
#
# Document: [1670]
# Cosine Similarity : 0.6640920639038086
#
#
# Document: [2180]
# Cosine Similarity : 0.6640917658805847
#
#
# Document: [108]
# Cosine Similarity : 0.6640681028366089
#
#
# Document: [251]
# Cosine Similarity : 0.6639928817749023
#
#
# Document: [1242]
# Cosine Similarity : 0.6639649868011475
#
#
# Document: [1662]
# Cosine Similarity : 0.6638851165771484
#
#
# Document: [334]
# Cosine Similarity : 0.6636835336685181
#
#
# Document: [1387]
# Cosine Similarity : 0.6636790037155151
#
#
# Document: [633]
# Cosine Similarity : 0.6636782884597778
#
#
# Document: [1816]
# Cosine Similarity : 0.6635284423828125
#
#
# Document: [1735]
# Cosine Similarity : 0.6634351015090942
#
#
# Document: [1217]
# Cosine Similarity : 0.6634129285812378
#
#
# Document: [426]
# Cosine Similarity : 0.6634129285812378
#
#
# Document: [699]
# Cosine Similarity : 0.663411021232605
#
#
# Document: [367]
# Cosine Similarity : 0.6633791923522949
#
#
# Document: [2084]
# Cosine Similarity : 0.663337767124176
#
#
# Document: [1259]
# Cosine Similarity : 0.6632595062255859
#
#
# Document: [1414]
# Cosine Similarity : 0.6631345748901367
#
#
# Document: [2003]
# Cosine Similarity : 0.6630505919456482
#
#
# Document: [599]
# Cosine Similarity : 0.6630461812019348
#
#
# Document: [919]
# Cosine Similarity : 0.6630043983459473
#
#
# Document: [2212]
# Cosine Similarity : 0.6629666090011597
#
#
# Document: [248]
# Cosine Similarity : 0.6628583073616028
#
#
# Document: [943]
# Cosine Similarity : 0.6627329587936401
#
#
# Document: [588]
# Cosine Similarity : 0.6626825332641602
#
#
# Document: [525]
# Cosine Similarity : 0.662585973739624
#
#
# Document: [222]
# Cosine Similarity : 0.6623309850692749
#
#
# Document: [1790]
# Cosine Similarity : 0.6623208522796631
#
#
# Document: [1541]
# Cosine Similarity : 0.66231769323349
#
#
# Document: [656]
# Cosine Similarity : 0.662316083908081
#
#
# Document: [1124]
# Cosine Similarity : 0.66227787733078
#
#
# Document: [1535]
# Cosine Similarity : 0.6622122526168823
#
#
# Document: [801]
# Cosine Similarity : 0.662146806716919
#
#
# Document: [730]
# Cosine Similarity : 0.6619651317596436
#
#
# Document: [179]
# Cosine Similarity : 0.6619155406951904
#
#
# Document: [1970]
# Cosine Similarity : 0.6618685126304626
#
#
# Document: [1360]
# Cosine Similarity : 0.6618326306343079
#
#
# Document: [1354]
# Cosine Similarity : 0.6617233753204346
#
#
# Document: [1637]
# Cosine Similarity : 0.6616450548171997
#
#
# Document: [2171]
# Cosine Similarity : 0.6616284847259521
#
#
# Document: [1276]
# Cosine Similarity : 0.661620020866394
#
#
# Document: [683]
# Cosine Similarity : 0.6616145372390747
#
#
# Document: [1019]
# Cosine Similarity : 0.661585807800293
#
#
# Document: [639]
# Cosine Similarity : 0.6615396738052368
#
#
# Document: [1085]
# Cosine Similarity : 0.6615093350410461
#
#
# Document: [1341]
# Cosine Similarity : 0.6615001559257507
#
#
# Document: [1939]
# Cosine Similarity : 0.661476194858551
#
#
# Document: [998]
# Cosine Similarity : 0.6613817811012268
#
#
# Document: [1005]
# Cosine Similarity : 0.6613804697990417
#
#
# Document: [1293]
# Cosine Similarity : 0.6613759994506836
#
#
# Document: [870]
# Cosine Similarity : 0.6613728404045105
#
#
# Document: [1878]
# Cosine Similarity : 0.6613268852233887
#
#
# Document: [2222]
# Cosine Similarity : 0.6613249778747559
#
#
# Document: [629]
# Cosine Similarity : 0.6613215208053589
#
#
# Document: [1681]
# Cosine Similarity : 0.6613177061080933
#
#
# Document: [1623]
# Cosine Similarity : 0.6612526178359985
#
#
# Document: [1682]
# Cosine Similarity : 0.6612507104873657
#
#
# Document: [1526]
# Cosine Similarity : 0.6612485647201538
#
#
# Document: [2164]
# Cosine Similarity : 0.6611526012420654
#
#
# Document: [1595]
# Cosine Similarity : 0.6611378788948059
#
#
# Document: [1821]
# Cosine Similarity : 0.661119818687439
#
#
# Document: [1166]
# Cosine Similarity : 0.661060094833374
#
#
# Document: [1284]
# Cosine Similarity : 0.6609696745872498
#
#
# Document: [1227]
# Cosine Similarity : 0.6609017848968506
#
#
# Document: [13]
# Cosine Similarity : 0.6608803868293762
#
#
# Document: [85]
# Cosine Similarity : 0.6608803868293762
#
#
# Document: [1545]
# Cosine Similarity : 0.6608718633651733
#
#
# Document: [831]
# Cosine Similarity : 0.6606714129447937
#
#
# Document: [306]
# Cosine Similarity : 0.660658597946167
#
#
# Document: [414]
# Cosine Similarity : 0.6604206562042236
#
#
# Document: [1021]
# Cosine Similarity : 0.6604085564613342
#
#
# Document: [839]
# Cosine Similarity : 0.6604085564613342
#
#
# Document: [110]
# Cosine Similarity : 0.6603518724441528
#
#
# Document: [1402]
# Cosine Similarity : 0.6602359414100647
#
#
# Document: [778]
# Cosine Similarity : 0.6602065563201904
#
#
# Document: [430]
# Cosine Similarity : 0.6602065563201904
#
#
# Document: [1931]
# Cosine Similarity : 0.660146951675415
#
#
# Document: [978]
# Cosine Similarity : 0.6601120233535767
#
#
# Document: [438]
# Cosine Similarity : 0.6600801944732666
#
#
# Document: [372]
# Cosine Similarity : 0.6600432991981506
#
#
# Document: [1343]
# Cosine Similarity : 0.6600379347801208
#
#
# Document: [468]
# Cosine Similarity : 0.6599169969558716
#
#
# Document: [211]
# Cosine Similarity : 0.6598782539367676
#
#
# Document: [536]
# Cosine Similarity : 0.659785270690918
#
#
# Document: [851]
# Cosine Similarity : 0.6596860289573669
#
#
# Document: [757]
# Cosine Similarity : 0.6596090793609619
#
#
# Document: [968]
# Cosine Similarity : 0.6595370769500732
#
#
# Document: [2123]
# Cosine Similarity : 0.6595156192779541
#
#
# Document: [1707]
# Cosine Similarity : 0.6593678593635559
#
#
# Document: [1990]
# Cosine Similarity : 0.6593533754348755
#
#
# Document: [802]
# Cosine Similarity : 0.6592556834220886
#
#
# Document: [268]
# Cosine Similarity : 0.65910804271698
#
#
# Document: [694]
# Cosine Similarity : 0.6590234637260437
#
#
# Document: [238]
# Cosine Similarity : 0.6590140461921692
#
#
# Document: [448]
# Cosine Similarity : 0.658998429775238
#
#
# Document: [17]
# Cosine Similarity : 0.6588246822357178
#
#
# Document: [1376]
# Cosine Similarity : 0.6587822437286377
#
#
# Document: [1891]
# Cosine Similarity : 0.6587804555892944
#
#
# Document: [509]
# Cosine Similarity : 0.658710777759552
#
#
# Document: [969]
# Cosine Similarity : 0.6587027311325073
#
#
# Document: [967]
# Cosine Similarity : 0.6586921215057373
#
#
# Document: [841]
# Cosine Similarity : 0.6586703062057495
#
#
# Document: [498]
# Cosine Similarity : 0.658646821975708
#
#
# Document: [2050]
# Cosine Similarity : 0.6585695147514343
#
#
# Document: [1216]
# Cosine Similarity : 0.6585604548454285
#
#
# Document: [2101]
# Cosine Similarity : 0.6585202217102051
#
#
# Document: [1835]
# Cosine Similarity : 0.6583585739135742
#
#
# Document: [1254]
# Cosine Similarity : 0.658336877822876
#
#
# Document: [613]
# Cosine Similarity : 0.658256471157074
#
#
# Document: [1770]
# Cosine Similarity : 0.6582561731338501
#
#
# Document: [56]
# Cosine Similarity : 0.658234179019928
#
#
# Document: [345]
# Cosine Similarity : 0.6582090258598328
#
#
# Document: [459]
# Cosine Similarity : 0.6580734848976135
#
#
# Document: [1887]
# Cosine Similarity : 0.6580423712730408
#
#
# Document: [710]
# Cosine Similarity : 0.6579431295394897
#
#
# Document: [1570]
# Cosine Similarity : 0.6579360961914062
#
#
# Document: [375]
# Cosine Similarity : 0.6578224301338196
#
#
# Document: [1962]
# Cosine Similarity : 0.6578173637390137
#
#
# Document: [556]
# Cosine Similarity : 0.6578131914138794
#
#
# Document: [746]
# Cosine Similarity : 0.6577901840209961
#
#
# Document: [868]
# Cosine Similarity : 0.6577855348587036
#
#
# Document: [558]
# Cosine Similarity : 0.6576837301254272
#
#
# Document: [608]
# Cosine Similarity : 0.6576762199401855
#
#
# Document: [780]
# Cosine Similarity : 0.6576654314994812
#
#
# Document: [1395]
# Cosine Similarity : 0.6576571464538574
#
#
# Document: [1673]
# Cosine Similarity : 0.6576124429702759
#
#
# Document: [993]
# Cosine Similarity : 0.6576041579246521
#
#
# Document: [1474]
# Cosine Similarity : 0.6575499773025513
#
#
# Document: [933]
# Cosine Similarity : 0.6574954986572266
#
#
# Document: [368]
# Cosine Similarity : 0.6574630737304688
#
#
# Document: [1782]
# Cosine Similarity : 0.6573083400726318
#
#
# Document: [725]
# Cosine Similarity : 0.657227635383606
#
#
# Document: [1664]
# Cosine Similarity : 0.657191276550293
#
#
# Document: [957]
# Cosine Similarity : 0.6570786237716675
#
#
# Document: [1706]
# Cosine Similarity : 0.6570526361465454
#
#
# Document: [1099]
# Cosine Similarity : 0.6569815874099731
#
#
# Document: [2096]
# Cosine Similarity : 0.6569201946258545
#
#
# Document: [769]
# Cosine Similarity : 0.6568335294723511
#
#
# Document: [1246]
# Cosine Similarity : 0.6567499041557312
#
#
# Document: [1194]
# Cosine Similarity : 0.6567056179046631
#
#
# Document: [1590]
# Cosine Similarity : 0.6566219329833984
#
#
# Document: [2122]
# Cosine Similarity : 0.6565916538238525
#
#
# Document: [924]
# Cosine Similarity : 0.6564961075782776
#
#
# Document: [182]
# Cosine Similarity : 0.656470775604248
#
#
# Document: [531]
# Cosine Similarity : 0.6564571857452393
#
#
# Document: [1533]
# Cosine Similarity : 0.6563162803649902
#
#
# Document: [1326]
# Cosine Similarity : 0.656296968460083
#
#
# Document: [1219]
# Cosine Similarity : 0.6562767028808594
#
#
# Document: [1499]
# Cosine Similarity : 0.6562690734863281
#
#
# Document: [1205]
# Cosine Similarity : 0.6562212705612183
#
#
# Document: [1952]
# Cosine Similarity : 0.6561794281005859
#
#
# Document: [2091]
# Cosine Similarity : 0.6561093330383301
#
#
# Document: [1033]
# Cosine Similarity : 0.655972421169281
#
#
# Document: [1070]
# Cosine Similarity : 0.6559416055679321
#
#
# Document: [2159]
# Cosine Similarity : 0.655838131904602
#
#
# Document: [2155]
# Cosine Similarity : 0.6557928323745728
#
#
# Document: [1450]
# Cosine Similarity : 0.6557403802871704
#
#
# Document: [361]
# Cosine Similarity : 0.6557061076164246
#
#
# Document: [1948]
# Cosine Similarity : 0.6553963422775269
#
#
# Document: [99]
# Cosine Similarity : 0.6553323268890381
#
#
# Document: [1568]
# Cosine Similarity : 0.6552718877792358
#
#
# Document: [7]
# Cosine Similarity : 0.6552406549453735
#
#
# Document: [881]
# Cosine Similarity : 0.6551093459129333
#
#
# Document: [401]
# Cosine Similarity : 0.6549246311187744
#
#
# Document: [2213]
# Cosine Similarity : 0.6549245715141296
#
#
# Document: [2163]
# Cosine Similarity : 0.6548836827278137
#
#
# Document: [1009]
# Cosine Similarity : 0.6548506617546082
#
#
# Document: [1530]
# Cosine Similarity : 0.6548361778259277
#
#
# Document: [2167]
# Cosine Similarity : 0.654773473739624
#
#
# Document: [721]
# Cosine Similarity : 0.654773473739624
#
#
# Document: [1559]
# Cosine Similarity : 0.6545896530151367
#
#
# Document: [510]
# Cosine Similarity : 0.6545593738555908
#
#
# Document: [265]
# Cosine Similarity : 0.6545593738555908
#
#
# Document: [1747]
# Cosine Similarity : 0.6545116901397705
#
#
# Document: [593]
# Cosine Similarity : 0.6544872522354126
#
#
# Document: [32]
# Cosine Similarity : 0.654332160949707
#
#
# Document: [659]
# Cosine Similarity : 0.6542466878890991
#
#
# Document: [125]
# Cosine Similarity : 0.6542462110519409
#
#
# Document: [2019]
# Cosine Similarity : 0.6542342901229858
#
#
# Document: [1562]
# Cosine Similarity : 0.654073178768158
#
#
# Document: [1553]
# Cosine Similarity : 0.6540226936340332
#
#
# Document: [1317]
# Cosine Similarity : 0.6539928913116455
#
#
# Document: [58]
# Cosine Similarity : 0.6539669632911682
#
#
# Document: [2031]
# Cosine Similarity : 0.6539591550827026
#
#
# Document: [786]
# Cosine Similarity : 0.6538739204406738
#
#
# Document: [696]
# Cosine Similarity : 0.6538551449775696
#
#
# Document: [1728]
# Cosine Similarity : 0.6538530588150024
#
#
# Document: [1851]
# Cosine Similarity : 0.6537978053092957
#
#
# Document: [947]
# Cosine Similarity : 0.6537219285964966
#
#
# Document: [750]
# Cosine Similarity : 0.6535636186599731
#
#
# Document: [1123]
# Cosine Similarity : 0.6535516977310181
#
#
# Document: [1731]
# Cosine Similarity : 0.6535213589668274
#
#
# Document: [641]
# Cosine Similarity : 0.653497576713562
#
#
# Document: [218]
# Cosine Similarity : 0.6534814238548279
#
#
# Document: [552]
# Cosine Similarity : 0.6534682512283325
#
#
# Document: [1018]
# Cosine Similarity : 0.6533774137496948
#
#
# Document: [147]
# Cosine Similarity : 0.653372585773468
#
#
# Document: [1694]
# Cosine Similarity : 0.6532971262931824
#
#
# Document: [1225]
# Cosine Similarity : 0.6532219648361206
#
#
# Document: [1861]
# Cosine Similarity : 0.6531261205673218
#
#
# Document: [1604]
# Cosine Similarity : 0.653023362159729
#
#
# Document: [1776]
# Cosine Similarity : 0.6530126333236694
#
#
# Document: [145]
# Cosine Similarity : 0.6529817581176758
#
#
# Document: [550]
# Cosine Similarity : 0.652849018573761
#
#
# Document: [804]
# Cosine Similarity : 0.6528118848800659
#
#
# Document: [8]
# Cosine Similarity : 0.652791440486908
#
#
# Document: [400]
# Cosine Similarity : 0.6527825593948364
#
#
# Document: [1097]
# Cosine Similarity : 0.6527303457260132
#
#
# Document: [1325]
# Cosine Similarity : 0.6527303457260132
#
#
# Document: [260]
# Cosine Similarity : 0.652706503868103
#
#
# Document: [1307]
# Cosine Similarity : 0.6525896787643433
#
#
# Document: [1413]
# Cosine Similarity : 0.6525669097900391
#
#
# Document: [1937]
# Cosine Similarity : 0.6525039076805115
#
#
# Document: [1367]
# Cosine Similarity : 0.6525039076805115
#
#
# Document: [16]
# Cosine Similarity : 0.6524799466133118
#
#
# Document: [737]
# Cosine Similarity : 0.6524617075920105
#
#
# Document: [63]
# Cosine Similarity : 0.6524114608764648
#
#
# Document: [1632]
# Cosine Similarity : 0.6522126793861389
#
#
# Document: [1344]
# Cosine Similarity : 0.6521883010864258
#
#
# Document: [1478]
# Cosine Similarity : 0.6521826386451721
#
#
# Document: [1949]
# Cosine Similarity : 0.6521684527397156
#
#
# Document: [2131]
# Cosine Similarity : 0.6521166563034058
#
#
# Document: [466]
# Cosine Similarity : 0.6520864367485046
#
#
# Document: [1749]
# Cosine Similarity : 0.6520575881004333
#
#
# Document: [1951]
# Cosine Similarity : 0.6520394682884216
#
#
# Document: [958]
# Cosine Similarity : 0.6520373225212097
#
#
# Document: [906]
# Cosine Similarity : 0.6518419981002808
#
#
# Document: [1328]
# Cosine Similarity : 0.6518251299858093
#
#
# Document: [95]
# Cosine Similarity : 0.6518048048019409
#
#
# Document: [445]
# Cosine Similarity : 0.6517387628555298
#
#
# Document: [1465]
# Cosine Similarity : 0.6517189741134644
#
#
# Document: [1001]
# Cosine Similarity : 0.6517106890678406
#
#
# Document: [974]
# Cosine Similarity : 0.6516505479812622
#
#
# Document: [1257]
# Cosine Similarity : 0.6515698432922363
#
#
# Document: [952]
# Cosine Similarity : 0.6515579223632812
#
#
# Document: [1540]
# Cosine Similarity : 0.6515467166900635
#
#
# Document: [62]
# Cosine Similarity : 0.6513102054595947
#
#
# Document: [1920]
# Cosine Similarity : 0.6512259840965271
#
#
# Document: [1429]
# Cosine Similarity : 0.6511389017105103
#
#
# Document: [1998]
# Cosine Similarity : 0.6511169672012329
#
#
# Document: [632]
# Cosine Similarity : 0.6510245203971863
#
#
# Document: [2109]
# Cosine Similarity : 0.6509671211242676
#
#
# Document: [272]
# Cosine Similarity : 0.650931179523468
#
#
# Document: [1727]
# Cosine Similarity : 0.6508116126060486
#
#
# Document: [1012]
# Cosine Similarity : 0.6508067846298218
#
#
# Document: [1359]
# Cosine Similarity : 0.6508037447929382
#
#
# Document: [1870]
# Cosine Similarity : 0.65073561668396
#
#
# Document: [1671]
# Cosine Similarity : 0.650735080242157
#
#
# Document: [1850]
# Cosine Similarity : 0.6505621671676636
#
#
# Document: [862]
# Cosine Similarity : 0.6504594683647156
#
#
# Document: [1128]
# Cosine Similarity : 0.6504249572753906
#
#
# Document: [1150]
# Cosine Similarity : 0.6503628492355347
#
#
# Document: [1255]
# Cosine Similarity : 0.6503550410270691
#
#
# Document: [1511]
# Cosine Similarity : 0.650349497795105
#
#
# Document: [1594]
# Cosine Similarity : 0.6502938270568848
#
#
# Document: [732]
# Cosine Similarity : 0.6502796411514282
#
#
# Document: [2093]
# Cosine Similarity : 0.6502765417098999
#
#
# Document: [22]
# Cosine Similarity : 0.650200605392456
#
#
# Document: [691]
# Cosine Similarity : 0.650100588798523
#
#
# Document: [2197]
# Cosine Similarity : 0.6500808596611023
#
#
# Document: [703]
# Cosine Similarity : 0.6500777006149292
#
#
# Document: [966]
# Cosine Similarity : 0.6500361561775208
#
#
# Document: [1129]
# Cosine Similarity : 0.6497954726219177
#
#
# Document: [1775]
# Cosine Similarity : 0.6497647762298584
#
#
# Document: [432]
# Cosine Similarity : 0.6495901942253113
#
#
# Document: [488]
# Cosine Similarity : 0.6495855450630188
#
#
# Document: [486]
# Cosine Similarity : 0.649581789970398
#
#
# Document: [1651]
# Cosine Similarity : 0.6495617032051086
#
#
# Document: [318]
# Cosine Similarity : 0.6494045257568359
#
#
# Document: [541]
# Cosine Similarity : 0.6493493318557739
#
#
# Document: [34]
# Cosine Similarity : 0.6493192315101624
#
#
# Document: [884]
# Cosine Similarity : 0.6491819024085999
#
#
# Document: [1635]
# Cosine Similarity : 0.6491819024085999
#
#
# Document: [2214]
# Cosine Similarity : 0.6491482257843018
#
#
# Document: [489]
# Cosine Similarity : 0.6491092443466187
#
#
# Document: [1250]
# Cosine Similarity : 0.6491016745567322
#
#
# Document: [353]
# Cosine Similarity : 0.6490718722343445
#
#
# Document: [1537]
# Cosine Similarity : 0.6490449905395508
#
#
# Document: [728]
# Cosine Similarity : 0.6488439440727234
#
#
# Document: [1347]
# Cosine Similarity : 0.6487894654273987
#
#
# Document: [343]
# Cosine Similarity : 0.6487882137298584
#
#
# Document: [55]
# Cosine Similarity : 0.6486872434616089
#
#
# Document: [23]
# Cosine Similarity : 0.6486212015151978
#
#
# Document: [302]
# Cosine Similarity : 0.6484801173210144
#
#
# Document: [813]
# Cosine Similarity : 0.6484380960464478
#
#
# Document: [990]
# Cosine Similarity : 0.6483672857284546
#
#
# Document: [1896]
# Cosine Similarity : 0.6482268571853638
#
#
# Document: [985]
# Cosine Similarity : 0.6481523513793945
#
#
# Document: [1391]
# Cosine Similarity : 0.6480794548988342
#
#
# Document: [173]
# Cosine Similarity : 0.6480298042297363
#
#
# Document: [1239]
# Cosine Similarity : 0.6479924321174622
#
#
# Document: [2051]
# Cosine Similarity : 0.6479884386062622
#
#
# Document: [434]
# Cosine Similarity : 0.6479683518409729
#
#
# Document: [548]
# Cosine Similarity : 0.6478004455566406
#
#
# Document: [1515]
# Cosine Similarity : 0.6477879285812378
#
#
# Document: [676]
# Cosine Similarity : 0.6476997137069702
#
#
# Document: [1709]
# Cosine Similarity : 0.6476702094078064
#
#
# Document: [1147]
# Cosine Similarity : 0.6476022005081177
#
#
# Document: [323]
# Cosine Similarity : 0.6475021839141846
#
#
# Document: [1518]
# Cosine Similarity : 0.6474928259849548
#
#
# Document: [2055]
# Cosine Similarity : 0.6474928259849548
#
#
# Document: [1527]
# Cosine Similarity : 0.6474151015281677
#
#
# Document: [126]
# Cosine Similarity : 0.647374153137207
#
#
# Document: [325]
# Cosine Similarity : 0.6473566889762878
#
#
# Document: [186]
# Cosine Similarity : 0.6473507881164551
#
#
# Document: [1611]
# Cosine Similarity : 0.6473371982574463
#
#
# Document: [487]
# Cosine Similarity : 0.6471036672592163
#
#
# Document: [805]
# Cosine Similarity : 0.6468216776847839
#
#
# Document: [1006]
# Cosine Similarity : 0.6468198895454407
#
#
# Document: [736]
# Cosine Similarity : 0.6467675566673279
#
#
# Document: [867]
# Cosine Similarity : 0.6466389298439026
#
#
# Document: [1473]
# Cosine Similarity : 0.6466070413589478
#
#
# Document: [759]
# Cosine Similarity : 0.646369457244873
#
#
# Document: [653]
# Cosine Similarity : 0.6463437080383301
#
#
# Document: [1801]
# Cosine Similarity : 0.646306574344635
#
#
# Document: [389]
# Cosine Similarity : 0.6462365388870239
#
#
# Document: [94]
# Cosine Similarity : 0.6462224721908569
#
#
# Document: [720]
# Cosine Similarity : 0.646221935749054
#
#
# Document: [1398]
# Cosine Similarity : 0.6460762023925781
#
#
# Document: [787]
# Cosine Similarity : 0.6460460424423218
#
#
# Document: [1443]
# Cosine Similarity : 0.6459177136421204
#
#
# Document: [646]
# Cosine Similarity : 0.6458803415298462
#
#
# Document: [243]
# Cosine Similarity : 0.6458560228347778
#
#
# Document: [1996]
# Cosine Similarity : 0.6458063721656799
#
#
# Document: [1505]
# Cosine Similarity : 0.6457958221435547
#
#
# Document: [1486]
# Cosine Similarity : 0.6457647681236267
#
#
# Document: [2099]
# Cosine Similarity : 0.6457005143165588
#
#
# Document: [408]
# Cosine Similarity : 0.6455138921737671
#
#
# Document: [1784]
# Cosine Similarity : 0.6455110907554626
#
#
# Document: [1953]
# Cosine Similarity : 0.6454746127128601
#
#
# Document: [1100]
# Cosine Similarity : 0.6453876495361328
#
#
# Document: [1379]
# Cosine Similarity : 0.6452959775924683
#
#
# Document: [765]
# Cosine Similarity : 0.645261287689209
#
#
# Document: [289]
# Cosine Similarity : 0.6451129913330078
#
#
# Document: [671]
# Cosine Similarity : 0.6450951099395752
#
#
# Document: [1983]
# Cosine Similarity : 0.6449511051177979
#
#
# Document: [415]
# Cosine Similarity : 0.6448891162872314
#
#
# Document: [78]
# Cosine Similarity : 0.6448841691017151
#
#
# Document: [235]
# Cosine Similarity : 0.6447796821594238
#
#
# Document: [1374]
# Cosine Similarity : 0.6447278261184692
#
#
# Document: [1894]
# Cosine Similarity : 0.6447278261184692
#
#
# Document: [237]
# Cosine Similarity : 0.6447223424911499
#
#
# Document: [1955]
# Cosine Similarity : 0.6446964740753174
#
#
# Document: [1593]
# Cosine Similarity : 0.644691526889801
#
#
# Document: [109]
# Cosine Similarity : 0.6446605920791626
#
#
# Document: [956]
# Cosine Similarity : 0.644660472869873
#
#
# Document: [1407]
# Cosine Similarity : 0.644635796546936
#
#
# Document: [1646]
# Cosine Similarity : 0.644567608833313
#
#
# Document: [328]
# Cosine Similarity : 0.6445570588111877
#
#
# Document: [2005]
# Cosine Similarity : 0.6445445418357849
#
#
# Document: [809]
# Cosine Similarity : 0.6445209980010986
#
#
# Document: [333]
# Cosine Similarity : 0.6444512605667114
#
#
# Document: [1757]
# Cosine Similarity : 0.6444364786148071
#
#
# Document: [3]
# Cosine Similarity : 0.6444150805473328
#
#
# Document: [1680]
# Cosine Similarity : 0.6444111466407776
#
#
# Document: [346]
# Cosine Similarity : 0.6443372964859009
#
#
# Document: [816]
# Cosine Similarity : 0.6443077921867371
#
#
# Document: [2077]
# Cosine Similarity : 0.6442441940307617
#
#
# Document: [2079]
# Cosine Similarity : 0.6442441940307617
#
#
# Document: [138]
# Cosine Similarity : 0.6441454291343689
#
#
# Document: [1310]
# Cosine Similarity : 0.6440577507019043
#
#
# Document: [1491]
# Cosine Similarity : 0.6439794301986694
#
#
# Document: [1563]
# Cosine Similarity : 0.6439549922943115
#
#
# Document: [1843]
# Cosine Similarity : 0.6439374089241028
#
#
# Document: [565]
# Cosine Similarity : 0.6439276933670044
#
#
# Document: [162]
# Cosine Similarity : 0.6438595056533813
#
#
# Document: [388]
# Cosine Similarity : 0.6438305377960205
#
#
# Document: [1957]
# Cosine Similarity : 0.6436320543289185
#
#
# Document: [1655]
# Cosine Similarity : 0.6432329416275024
#
#
# Document: [1753]
# Cosine Similarity : 0.6431270837783813
#
#
# Document: [326]
# Cosine Similarity : 0.6431096196174622
#
#
# Document: [1476]
# Cosine Similarity : 0.6430991291999817
#
#
# Document: [1558]
# Cosine Similarity : 0.6430532932281494
#
#
# Document: [1378]
# Cosine Similarity : 0.6429637670516968
#
#
# Document: [668]
# Cosine Similarity : 0.6429007649421692
#
#
# Document: [837]
# Cosine Similarity : 0.6429007649421692
#
#
# Document: [1756]
# Cosine Similarity : 0.6428896188735962
#
#
# Document: [854]
# Cosine Similarity : 0.642888605594635
#
#
# Document: [391]
# Cosine Similarity : 0.6428298950195312
#
#
# Document: [1315]
# Cosine Similarity : 0.6427929401397705
#
#
# Document: [2158]
# Cosine Similarity : 0.6427480578422546
#
#
# Document: [1814]
# Cosine Similarity : 0.6426358222961426
#
#
# Document: [1373]
# Cosine Similarity : 0.6426284313201904
#
#
# Document: [364]
# Cosine Similarity : 0.6425580978393555
#
#
# Document: [753]
# Cosine Similarity : 0.6425440311431885
#
#
# Document: [1805]
# Cosine Similarity : 0.6425440311431885
#
#
# Document: [1364]
# Cosine Similarity : 0.6425315737724304
#
#
# Document: [775]
# Cosine Similarity : 0.6423231363296509
#
#
# Document: [768]
# Cosine Similarity : 0.6422924399375916
#
#
# Document: [662]
# Cosine Similarity : 0.642253041267395
#
#
# Document: [81]
# Cosine Similarity : 0.6421490907669067
#
#
# Document: [1447]
# Cosine Similarity : 0.6421258449554443
#
#
# Document: [897]
# Cosine Similarity : 0.6420591473579407
#
#
# Document: [305]
# Cosine Similarity : 0.6418884992599487
#
#
# Document: [1582]
# Cosine Similarity : 0.6418546438217163
#
#
# Document: [1950]
# Cosine Similarity : 0.6417784094810486
#
#
# Document: [1913]
# Cosine Similarity : 0.6417603492736816
#
#
# Document: [1279]
# Cosine Similarity : 0.641541600227356
#
#
# Document: [278]
# Cosine Similarity : 0.6415287852287292
#
#
# Document: [1300]
# Cosine Similarity : 0.6414559483528137
#
#
# Document: [1057]
# Cosine Similarity : 0.6414443254470825
#
#
# Document: [955]
# Cosine Similarity : 0.6413822174072266
#
#
# Document: [1409]
# Cosine Similarity : 0.6413304805755615
#
#
# Document: [11]
# Cosine Similarity : 0.6412991285324097
#
#
# Document: [989]
# Cosine Similarity : 0.6411354541778564
#
#
# Document: [2009]
# Cosine Similarity : 0.64100182056427
#
#
# Document: [619]
# Cosine Similarity : 0.6409362554550171
#
#
# Document: [1750]
# Cosine Similarity : 0.6408538222312927
#
#
# Document: [647]
# Cosine Similarity : 0.6408490538597107
#
#
# Document: [1264]
# Cosine Similarity : 0.6408414840698242
#
#
# Document: [2203]
# Cosine Similarity : 0.6407231688499451
#
#
# Document: [1783]
# Cosine Similarity : 0.6406301259994507
#
#
# Document: [1038]
# Cosine Similarity : 0.6406279802322388
#
#
# Document: [680]
# Cosine Similarity : 0.6406190395355225
#
#
# Document: [845]
# Cosine Similarity : 0.6405309438705444
#
#
# Document: [623]
# Cosine Similarity : 0.6404634714126587
#
#
# Document: [1026]
# Cosine Similarity : 0.640357255935669
#
#
# Document: [1164]
# Cosine Similarity : 0.6403318047523499
#
#
# Document: [370]
# Cosine Similarity : 0.6403061151504517
#
#
# Document: [1592]
# Cosine Similarity : 0.6403010487556458
#
#
# Document: [2147]
# Cosine Similarity : 0.6401645541191101
#
#
# Document: [2177]
# Cosine Similarity : 0.6400824189186096
#
#
# Document: [1892]
# Cosine Similarity : 0.640076756477356
#
#
# Document: [1168]
# Cosine Similarity : 0.639988362789154
#
#
# Document: [2063]
# Cosine Similarity : 0.6399356126785278
#
#
# Document: [1305]
# Cosine Similarity : 0.6399208307266235
#
#
# Document: [727]
# Cosine Similarity : 0.6399097442626953
#
#
# Document: [907]
# Cosine Similarity : 0.6399019956588745
#
#
# Document: [1542]
# Cosine Similarity : 0.6398091316223145
#
#
# Document: [1987]
# Cosine Similarity : 0.6398091316223145
#
#
# Document: [66]
# Cosine Similarity : 0.6397966146469116
#
#
# Document: [926]
# Cosine Similarity : 0.6397430896759033
#
#
# Document: [1800]
# Cosine Similarity : 0.6397430896759033
#
#
# Document: [1158]
# Cosine Similarity : 0.6397169232368469
#
#
# Document: [40]
# Cosine Similarity : 0.6396982669830322
#
#
# Document: [96]
# Cosine Similarity : 0.6396329402923584
#
#
# Document: [1313]
# Cosine Similarity : 0.6396322250366211
#
#
# Document: [1090]
# Cosine Similarity : 0.6396195292472839
#
#
# Document: [2080]
# Cosine Similarity : 0.6395782232284546
#
#
# Document: [1856]
# Cosine Similarity : 0.6395659446716309
#
#
# Document: [1612]
# Cosine Similarity : 0.639549970626831
#
#
# Document: [2081]
# Cosine Similarity : 0.6395332217216492
#
#
# Document: [1468]
# Cosine Similarity : 0.6394603848457336
#
#
# Document: [1884]
# Cosine Similarity : 0.6394169926643372
#
#
# Document: [1394]
# Cosine Similarity : 0.6393429040908813
#
#
# Document: [69]
# Cosine Similarity : 0.6393097043037415
#
#
# Document: [1971]
# Cosine Similarity : 0.6392995119094849
#
#
# Document: [1243]
# Cosine Similarity : 0.6391584277153015
#
#
# Document: [1738]
# Cosine Similarity : 0.6389215588569641
#
#
# Document: [1435]
# Cosine Similarity : 0.638906717300415
#
#
# Document: [893]
# Cosine Similarity : 0.6388651132583618
#
#
# Document: [539]
# Cosine Similarity : 0.6387907266616821
#
#
# Document: [2073]
# Cosine Similarity : 0.6387801766395569
#
#
# Document: [1746]
# Cosine Similarity : 0.6386847496032715
#
#
# Document: [945]
# Cosine Similarity : 0.6386756896972656
#
#
# Document: [1792]
# Cosine Similarity : 0.6385588645935059
#
#
# Document: [1226]
# Cosine Similarity : 0.6384459137916565
#
#
# Document: [904]
# Cosine Similarity : 0.6383680105209351
#
#
# Document: [533]
# Cosine Similarity : 0.6382732391357422
#
#
# Document: [2135]
# Cosine Similarity : 0.638267457485199
#
#
# Document: [1352]
# Cosine Similarity : 0.6381632685661316
#
#
# Document: [1157]
# Cosine Similarity : 0.6381626129150391
#
#
# Document: [894]
# Cosine Similarity : 0.6381626129150391
#
#
# Document: [1471]
# Cosine Similarity : 0.637879490852356
#
#
# Document: [954]
# Cosine Similarity : 0.6378587484359741
#
#
# Document: [153]
# Cosine Similarity : 0.6377692222595215
#
#
# Document: [48]
# Cosine Similarity : 0.6377102732658386
#
#
# Document: [1233]
# Cosine Similarity : 0.6376760601997375
#
#
# Document: [2011]
# Cosine Similarity : 0.6376636028289795
#
#
# Document: [1069]
# Cosine Similarity : 0.6376311182975769
#
#
# Document: [1668]
# Cosine Similarity : 0.6376309394836426
#
#
# Document: [1111]
# Cosine Similarity : 0.6376215219497681
#
#
# Document: [1633]
# Cosine Similarity : 0.6375952363014221
#
#
# Document: [631]
# Cosine Similarity : 0.6375906467437744
#
#
# Document: [2094]
# Cosine Similarity : 0.6375037431716919
#
#
# Document: [1769]
# Cosine Similarity : 0.6374772787094116
#
#
# Document: [403]
# Cosine Similarity : 0.6374658346176147
#
#
# Document: [132]
# Cosine Similarity : 0.637434720993042
#
#
# Document: [824]
# Cosine Similarity : 0.6374338865280151
#
#
# Document: [1084]
# Cosine Similarity : 0.6374282240867615
#
#
# Document: [936]
# Cosine Similarity : 0.6374254822731018
#
#
# Document: [682]
# Cosine Similarity : 0.6373820900917053
#
#
# Document: [980]
# Cosine Similarity : 0.6373124718666077
#
#
# Document: [341]
# Cosine Similarity : 0.6372441649436951
#
#
# Document: [1411]
# Cosine Similarity : 0.6371542811393738
#
#
# Document: [1176]
# Cosine Similarity : 0.637134850025177
#
#
# Document: [693]
# Cosine Similarity : 0.6370841264724731
#
#
# Document: [1046]
# Cosine Similarity : 0.6369668245315552
#
#
# Document: [1330]
# Cosine Similarity : 0.6367954611778259
#
#
# Document: [93]
# Cosine Similarity : 0.6367911100387573
#
#
# Document: [1475]
# Cosine Similarity : 0.6367123126983643
#
#
# Document: [1945]
# Cosine Similarity : 0.6366558074951172
#
#
# Document: [873]
# Cosine Similarity : 0.6366049647331238
#
#
# Document: [1416]
# Cosine Similarity : 0.636559784412384
#
#
# Document: [136]
# Cosine Similarity : 0.6365503668785095
#
#
# Document: [1283]
# Cosine Similarity : 0.6364893913269043
#
#
# Document: [292]
# Cosine Similarity : 0.6364770531654358
#
#
# Document: [1927]
# Cosine Similarity : 0.6364222764968872
#
#
# Document: [771]
# Cosine Similarity : 0.636376142501831
#
#
# Document: [114]
# Cosine Similarity : 0.6363447308540344
#
#
# Document: [240]
# Cosine Similarity : 0.6363011598587036
#
#
# Document: [634]
# Cosine Similarity : 0.6362777352333069
#
#
# Document: [1269]
# Cosine Similarity : 0.6362684965133667
#
#
# Document: [692]
# Cosine Similarity : 0.6362581253051758
#
#
# Document: [1509]
# Cosine Similarity : 0.6361527442932129
#
#
# Document: [704]
# Cosine Similarity : 0.6360912322998047
#
#
# Document: [1105]
# Cosine Similarity : 0.6360778212547302
#
#
# Document: [269]
# Cosine Similarity : 0.6360649466514587
#
#
# Document: [1914]
# Cosine Similarity : 0.6359301805496216
#
#
# Document: [1613]
# Cosine Similarity : 0.6358513236045837
#
#
# Document: [1277]
# Cosine Similarity : 0.6356231570243835
#
#
# Document: [638]
# Cosine Similarity : 0.6353490352630615
#
#
# Document: [1817]
# Cosine Similarity : 0.6353268623352051
#
#
# Document: [1876]
# Cosine Similarity : 0.6353137493133545
#
#
# Document: [227]
# Cosine Similarity : 0.6352615356445312
#
#
# Document: [1525]
# Cosine Similarity : 0.6352211236953735
#
#
# Document: [518]
# Cosine Similarity : 0.6351132392883301
#
#
# Document: [2137]
# Cosine Similarity : 0.6349212527275085
#
#
# Document: [820]
# Cosine Similarity : 0.6348938941955566
#
#
# Document: [485]
# Cosine Similarity : 0.6348938941955566
#
#
# Document: [853]
# Cosine Similarity : 0.6348729133605957
#
#
# Document: [316]
# Cosine Similarity : 0.6347959041595459
#
#
# Document: [1371]
# Cosine Similarity : 0.6347944140434265
#
#
# Document: [650]
# Cosine Similarity : 0.6347652673721313
#
#
# Document: [140]
# Cosine Similarity : 0.634738564491272
#
#
# Document: [1180]
# Cosine Similarity : 0.6346197128295898
#
#
# Document: [1942]
# Cosine Similarity : 0.6346161365509033
#
#
# Document: [2022]
# Cosine Similarity : 0.6345033645629883
#
#
# Document: [2126]
# Cosine Similarity : 0.6344317197799683
#
#
# Document: [25]
# Cosine Similarity : 0.6342734098434448
#
#
# Document: [1625]
# Cosine Similarity : 0.6342046856880188
#
#
# Document: [846]
# Cosine Similarity : 0.6341767311096191
#
#
# Document: [1532]
# Cosine Similarity : 0.6341544389724731
#
#
# Document: [1696]
# Cosine Similarity : 0.6340868473052979
#
#
# Document: [1837]
# Cosine Similarity : 0.6340295076370239
#
#
# Document: [890]
# Cosine Similarity : 0.634006142616272
#
#
# Document: [566]
# Cosine Similarity : 0.6339558362960815
#
#
# Document: [1716]
# Cosine Similarity : 0.6338362693786621
#
#
# Document: [2041]
# Cosine Similarity : 0.6337423324584961
#
#
# Document: [788]
# Cosine Similarity : 0.6337423324584961
#
#
# Document: [959]
# Cosine Similarity : 0.633690357208252
#
#
# Document: [1589]
# Cosine Similarity : 0.6336503028869629
#
#
# Document: [1941]
# Cosine Similarity : 0.6335960030555725
#
#
# Document: [1650]
# Cosine Similarity : 0.63349848985672
#
#
# Document: [429]
# Cosine Similarity : 0.6334930658340454
#
#
# Document: [172]
# Cosine Similarity : 0.6332906484603882
#
#
# Document: [776]
# Cosine Similarity : 0.6332066655158997
#
#
# Document: [1101]
# Cosine Similarity : 0.6332066655158997
#
#
# Document: [1201]
# Cosine Similarity : 0.6331127882003784
#
#
# Document: [458]
# Cosine Similarity : 0.6330373883247375
#
#
# Document: [185]
# Cosine Similarity : 0.6329702138900757
#
#
# Document: [1011]
# Cosine Similarity : 0.6329221129417419
#
#
# Document: [970]
# Cosine Similarity : 0.6326950788497925
#
#
# Document: [451]
# Cosine Similarity : 0.6326848268508911
#
#
# Document: [1829]
# Cosine Similarity : 0.6326321959495544
#
#
# Document: [1844]
# Cosine Similarity : 0.6325926780700684
#
#
# Document: [1218]
# Cosine Similarity : 0.6325046420097351
#
#
# Document: [935]
# Cosine Similarity : 0.6325003504753113
#
#
# Document: [476]
# Cosine Similarity : 0.6324924826622009
#
#
# Document: [1370]
# Cosine Similarity : 0.632477879524231
#
#
# Document: [303]
# Cosine Similarity : 0.6324660778045654
#
#
# Document: [783]
# Cosine Similarity : 0.6324294209480286
#
#
# Document: [500]
# Cosine Similarity : 0.6324232220649719
#
#
# Document: [1900]
# Cosine Similarity : 0.6323943138122559
#
#
# Document: [1241]
# Cosine Similarity : 0.6323769092559814
#
#
# Document: [900]
# Cosine Similarity : 0.6323595643043518
#
#
# Document: [995]
# Cosine Similarity : 0.6323567628860474
#
#
# Document: [1285]
# Cosine Similarity : 0.6323446035385132
#
#
# Document: [917]
# Cosine Similarity : 0.632329523563385
#
#
# Document: [850]
# Cosine Similarity : 0.6322364807128906
#
#
# Document: [542]
# Cosine Similarity : 0.6320987343788147
#
#
# Document: [150]
# Cosine Similarity : 0.6320380568504333
#
#
# Document: [1404]
# Cosine Similarity : 0.6318216919898987
#
#
# Document: [456]
# Cosine Similarity : 0.6318216919898987
#
#
# Document: [77]
# Cosine Similarity : 0.6317538619041443
#
#
# Document: [1137]
# Cosine Similarity : 0.6317301988601685
#
#
# Document: [258]
# Cosine Similarity : 0.631684422492981
#
#
# Document: [409]
# Cosine Similarity : 0.6316385269165039
#
#
# Document: [994]
# Cosine Similarity : 0.631582498550415
#
#
# Document: [2057]
# Cosine Similarity : 0.6315745115280151
#
#
# Document: [1981]
# Cosine Similarity : 0.6312743425369263
#
#
# Document: [2023]
# Cosine Similarity : 0.6312130093574524
#
#
# Document: [681]
# Cosine Similarity : 0.6311426162719727
#
#
# Document: [1088]
# Cosine Similarity : 0.6311371922492981
#
#
# Document: [1736]
# Cosine Similarity : 0.6311017870903015
#
#
# Document: [675]
# Cosine Similarity : 0.6310394406318665
#
#
# Document: [1345]
# Cosine Similarity : 0.6309733390808105
#
#
# Document: [1023]
# Cosine Similarity : 0.6309680938720703
#
#
# Document: [1877]
# Cosine Similarity : 0.630929708480835
#
#
# Document: [2042]
# Cosine Similarity : 0.6308716535568237
#
#
# Document: [1214]
# Cosine Similarity : 0.6308655738830566
#
#
# Document: [1917]
# Cosine Similarity : 0.6307811737060547
#
#
# Document: [999]
# Cosine Similarity : 0.6305627822875977
#
#
# Document: [1508]
# Cosine Similarity : 0.6305580139160156
#
#
# Document: [329]
# Cosine Similarity : 0.6305316090583801
#
#
# Document: [1733]
# Cosine Similarity : 0.6304711103439331
#
#
# Document: [1886]
# Cosine Similarity : 0.6303540468215942
#
#
# Document: [508]
# Cosine Similarity : 0.630178689956665
#
#
# Document: [1113]
# Cosine Similarity : 0.6301285624504089
#
#
# Document: [690]
# Cosine Similarity : 0.6301087141036987
#
#
# Document: [1510]
# Cosine Similarity : 0.6300714015960693
#
#
# Document: [986]
# Cosine Similarity : 0.6300534605979919
#
#
# Document: [1609]
# Cosine Similarity : 0.6296972036361694
#
#
# Document: [979]
# Cosine Similarity : 0.6296731233596802
#
#
# Document: [1081]
# Cosine Similarity : 0.6295657157897949
#
#
# Document: [191]
# Cosine Similarity : 0.6294206380844116
#
#
# Document: [1301]
# Cosine Similarity : 0.6293538808822632
#
#
# Document: [927]
# Cosine Similarity : 0.6293514370918274
#
#
# Document: [263]
# Cosine Similarity : 0.6292517185211182
#
#
# Document: [202]
# Cosine Similarity : 0.6291092038154602
#
#
# Document: [284]
# Cosine Similarity : 0.6290967464447021
#
#
# Document: [557]
# Cosine Similarity : 0.6290085315704346
#
#
# Document: [1104]
# Cosine Similarity : 0.6289817094802856
#
#
# Document: [1881]
# Cosine Similarity : 0.6289427876472473
#
#
# Document: [215]
# Cosine Similarity : 0.6288632750511169
#
#
# Document: [1678]
# Cosine Similarity : 0.628847062587738
#
#
# Document: [1940]
# Cosine Similarity : 0.6288328170776367
#
#
# Document: [287]
# Cosine Similarity : 0.6287109851837158
#
#
# Document: [1932]
# Cosine Similarity : 0.62865149974823
#
#
# Document: [1153]
# Cosine Similarity : 0.6285036206245422
#
#
# Document: [1666]
# Cosine Similarity : 0.6284536123275757
#
#
# Document: [506]
# Cosine Similarity : 0.6283798217773438
#
#
# Document: [79]
# Cosine Similarity : 0.628311038017273
#
#
# Document: [377]
# Cosine Similarity : 0.6282875537872314
#
#
# Document: [2026]
# Cosine Similarity : 0.6282123327255249
#
#
# Document: [1965]
# Cosine Similarity : 0.6281309723854065
#
#
# Document: [1529]
# Cosine Similarity : 0.6280642151832581
#
#
# Document: [1311]
# Cosine Similarity : 0.628021776676178
#
#
# Document: [1145]
# Cosine Similarity : 0.6278460025787354
#
#
# Document: [1324]
# Cosine Similarity : 0.6278460025787354
#
#
# Document: [181]
# Cosine Similarity : 0.6278105974197388
#
#
# Document: [1503]
# Cosine Similarity : 0.6276681423187256
#
#
# Document: [1470]
# Cosine Similarity : 0.6276645064353943
#
#
# Document: [1172]
# Cosine Similarity : 0.6276184320449829
#
#
# Document: [335]
# Cosine Similarity : 0.6275979280471802
#
#
# Document: [1108]
# Cosine Similarity : 0.6275594234466553
#
#
# Document: [1897]
# Cosine Similarity : 0.6275371313095093
#
#
# Document: [779]
# Cosine Similarity : 0.627434492111206
#
#
# Document: [767]
# Cosine Similarity : 0.62743079662323
#
#
# Document: [865]
# Cosine Similarity : 0.6273772716522217
#
#
# Document: [497]
# Cosine Similarity : 0.6271851658821106
#
#
# Document: [1571]
# Cosine Similarity : 0.6271741390228271
#
#
# Document: [711]
# Cosine Similarity : 0.62715744972229
#
#
# Document: [2139]
# Cosine Similarity : 0.6269899606704712
#
#
# Document: [1885]
# Cosine Similarity : 0.6269587278366089
#
#
# Document: [1498]
# Cosine Similarity : 0.6269101500511169
#
#
# Document: [1482]
# Cosine Similarity : 0.6268155574798584
#
#
# Document: [758]
# Cosine Similarity : 0.6267154216766357
#
#
# Document: [1557]
# Cosine Similarity : 0.6265503168106079
#
#
# Document: [2067]
# Cosine Similarity : 0.6262353658676147
#
#
# Document: [478]
# Cosine Similarity : 0.6260022521018982
#
#
# Document: [1389]
# Cosine Similarity : 0.6259027719497681
#
#
# Document: [2108]
# Cosine Similarity : 0.6258834600448608
#
#
# Document: [460]
# Cosine Similarity : 0.6258810758590698
#
#
# Document: [394]
# Cosine Similarity : 0.6258713006973267
#
#
# Document: [1737]
# Cosine Similarity : 0.6258265972137451
#
#
# Document: [1350]
# Cosine Similarity : 0.6257361769676208
#
#
# Document: [295]
# Cosine Similarity : 0.6257250308990479
#
#
# Document: [480]
# Cosine Similarity : 0.6256959438323975
#
#
# Document: [1322]
# Cosine Similarity : 0.6256959438323975
#
#
# Document: [2175]
# Cosine Similarity : 0.625694215297699
#
#
# Document: [242]
# Cosine Similarity : 0.6255950927734375
#
#
# Document: [2053]
# Cosine Similarity : 0.6255446076393127
#
#
# Document: [581]
# Cosine Similarity : 0.6253628134727478
#
#
# Document: [1275]
# Cosine Similarity : 0.6253272891044617
#
#
# Document: [74]
# Cosine Similarity : 0.625286340713501
#
#
# Document: [1334]
# Cosine Similarity : 0.6252298355102539
#
#
# Document: [1628]
# Cosine Similarity : 0.6252068281173706
#
#
# Document: [1601]
# Cosine Similarity : 0.625030517578125
#
#
# Document: [2119]
# Cosine Similarity : 0.6249809265136719
#
#
# Document: [450]
# Cosine Similarity : 0.6249186396598816
#
#
# Document: [90]
# Cosine Similarity : 0.6248884797096252
#
#
# Document: [1215]
# Cosine Similarity : 0.6248688697814941
#
#
# Document: [1365]
# Cosine Similarity : 0.6248388290405273
#
#
# Document: [250]
# Cosine Similarity : 0.6248173713684082
#
#
# Document: [359]
# Cosine Similarity : 0.6246922016143799
#
#
# Document: [1044]
# Cosine Similarity : 0.6245098114013672
#
#
# Document: [928]
# Cosine Similarity : 0.6244791150093079
#
#
# Document: [1910]
# Cosine Similarity : 0.624439001083374
#
#
# Document: [532]
# Cosine Similarity : 0.624428391456604
#
#
# Document: [2013]
# Cosine Similarity : 0.6242926120758057
#
#
# Document: [2092]
# Cosine Similarity : 0.6242821216583252
#
#
# Document: [811]
# Cosine Similarity : 0.6242004632949829
#
#
# Document: [2060]
# Cosine Similarity : 0.6241938471794128
#
#
# Document: [1495]
# Cosine Similarity : 0.6241797804832458
#
#
# Document: [1386]
# Cosine Similarity : 0.6241575479507446
#
#
# Document: [1826]
# Cosine Similarity : 0.624129056930542
#
#
# Document: [2117]
# Cosine Similarity : 0.6239973902702332
#
#
# Document: [18]
# Cosine Similarity : 0.6239880323410034
#
#
# Document: [205]
# Cosine Similarity : 0.623906135559082
#
#
# Document: [1645]
# Cosine Similarity : 0.623857855796814
#
#
# Document: [384]
# Cosine Similarity : 0.6238366365432739
#
#
# Document: [1235]
# Cosine Similarity : 0.6238290071487427
#
#
# Document: [1396]
# Cosine Similarity : 0.6238207817077637
#
#
# Document: [1223]
# Cosine Similarity : 0.623777449131012
#
#
# Document: [327]
# Cosine Similarity : 0.6237664222717285
#
#
# Document: [499]
# Cosine Similarity : 0.6237223148345947
#
#
# Document: [1679]
# Cosine Similarity : 0.6236236095428467
#
#
# Document: [20]
# Cosine Similarity : 0.6236236095428467
#
#
# Document: [1569]
# Cosine Similarity : 0.6236157417297363
#
#
# Document: [2083]
# Cosine Similarity : 0.6236157417297363
#
#
# Document: [1338]
# Cosine Similarity : 0.6235626339912415
#
#
# Document: [1765]
# Cosine Similarity : 0.6234148740768433
#
#
# Document: [735]
# Cosine Similarity : 0.6232999563217163
#
#
# Document: [362]
# Cosine Similarity : 0.6231863498687744
#
#
# Document: [857]
# Cosine Similarity : 0.6230959296226501
#
#
# Document: [1079]
# Cosine Similarity : 0.6230752468109131
#
#
# Document: [1489]
# Cosine Similarity : 0.6227664947509766
#
#
# Document: [708]
# Cosine Similarity : 0.6227071285247803
#
#
# Document: [892]
# Cosine Similarity : 0.6227024793624878
#
#
# Document: [849]
# Cosine Similarity : 0.6226842999458313
#
#
# Document: [479]
# Cosine Similarity : 0.6226363182067871
#
#
# Document: [1224]
# Cosine Similarity : 0.622600793838501
#
#
# Document: [1946]
# Cosine Similarity : 0.6225216388702393
#
#
# Document: [1116]
# Cosine Similarity : 0.6224154829978943
#
#
# Document: [1676]
# Cosine Similarity : 0.6223193407058716
#
#
# Document: [2189]
# Cosine Similarity : 0.6222609877586365
#
#
# Document: [649]
# Cosine Similarity : 0.6222609877586365
#
#
# Document: [1677]
# Cosine Similarity : 0.6222086548805237
#
#
# Document: [1375]
# Cosine Similarity : 0.6221656799316406
#
#
# Document: [167]
# Cosine Similarity : 0.6220108270645142
#
#
# Document: [2184]
# Cosine Similarity : 0.6218729019165039
#
#
# Document: [321]
# Cosine Similarity : 0.6215125322341919
#
#
# Document: [1237]
# Cosine Similarity : 0.6214674711227417
#
#
# Document: [28]
# Cosine Similarity : 0.6214447021484375
#
#
# Document: [91]
# Cosine Similarity : 0.6214362382888794
#
#
# Document: [1966]
# Cosine Similarity : 0.6214255690574646
#
#
# Document: [1078]
# Cosine Similarity : 0.621277391910553
#
#
# Document: [52]
# Cosine Similarity : 0.6212287545204163
#
#
# Document: [1787]
# Cosine Similarity : 0.6211631894111633
#
#
# Document: [315]
# Cosine Similarity : 0.6209211349487305
#
#
# Document: [2121]
# Cosine Similarity : 0.6209126710891724
#
#
# Document: [411]
# Cosine Similarity : 0.6208695769309998
#
#
# Document: [1516]
# Cosine Similarity : 0.6206629276275635
#
#
# Document: [1107]
# Cosine Similarity : 0.6206287145614624
#
#
# Document: [950]
# Cosine Similarity : 0.6206041574478149
#
#
# Document: [1832]
# Cosine Similarity : 0.6206012964248657
#
#
# Document: [1483]
# Cosine Similarity : 0.6204047203063965
#
#
# Document: [212]
# Cosine Similarity : 0.6203864216804504
#
#
# Document: [2217]
# Cosine Similarity : 0.6203497648239136
#
#
# Document: [644]
# Cosine Similarity : 0.620349645614624
#
#
# Document: [600]
# Cosine Similarity : 0.6202050447463989
#
#
# Document: [1823]
# Cosine Similarity : 0.6201134920120239
#
#
# Document: [376]
# Cosine Similarity : 0.620064377784729
#
#
# Document: [440]
# Cosine Similarity : 0.6198934316635132
#
#
# Document: [219]
# Cosine Similarity : 0.6198440790176392
#
#
# Document: [1798]
# Cosine Similarity : 0.6197948455810547
#
#
# Document: [1802]
# Cosine Similarity : 0.619713544845581
#
#
# Document: [314]
# Cosine Similarity : 0.6196949481964111
#
#
# Document: [1369]
# Cosine Similarity : 0.6196582317352295
#
#
# Document: [337]
# Cosine Similarity : 0.6196581125259399
#
#
# Document: [1687]
# Cosine Similarity : 0.6196316480636597
#
#
# Document: [2120]
# Cosine Similarity : 0.6193513870239258
#
#
# Document: [1444]
# Cosine Similarity : 0.6193513870239258
#
#
# Document: [134]
# Cosine Similarity : 0.6192749738693237
#
#
# Document: [1767]
# Cosine Similarity : 0.6192179322242737
#
#
# Document: [1368]
# Cosine Similarity : 0.6191248297691345
#
#
# Document: [948]
# Cosine Similarity : 0.6191189885139465
#
#
# Document: [178]
# Cosine Similarity : 0.6190825700759888
#
#
# Document: [2098]
# Cosine Similarity : 0.6190569400787354
#
#
# Document: [363]
# Cosine Similarity : 0.6190534830093384
#
#
# Document: [698]
# Cosine Similarity : 0.6187781095504761
#
#
# Document: [1693]
# Cosine Similarity : 0.618682861328125
#
#
# Document: [393]
# Cosine Similarity : 0.6186709403991699
#
#
# Document: [1267]
# Cosine Similarity : 0.6186632513999939
#
#
# Document: [1212]
# Cosine Similarity : 0.6181551218032837
#
#
# Document: [825]
# Cosine Similarity : 0.6180886030197144
#
#
# Document: [1440]
# Cosine Similarity : 0.6180163621902466
#
#
# Document: [2048]
# Cosine Similarity : 0.6178985834121704
#
#
# Document: [1191]
# Cosine Similarity : 0.6178891062736511
#
#
# Document: [1810]
# ...
#
#
# Document: [1199]
# Cosine Similarity : 0.6059093475341797
#
#
# Document: [1839]
# Cosine Similarity : 0.6058759093284607
#
#
# Document: [2000]
# Cosine Similarity : 0.6057262420654297
#
#
# Document: [573]
# Cosine Similarity : 0.6054421663284302
#
#
# Document: [988]
# Cosine Similarity : 0.6052110195159912
#
#
# Document: [356]
# Cosine Similarity : 0.6051439642906189
#
#
# Document: [1958]
# Cosine Similarity : 0.6051434874534607
#
#
# Document: [1639]
# Cosine Similarity : 0.6051033735275269
#
#
# Document: [483]
# Cosine Similarity : 0.6048688888549805
#
#
# Document: [1256]
# Cosine Similarity : 0.6046346426010132
#
#
# Document: [1993]
# Cosine Similarity : 0.6045856475830078
#
#
# Document: [1356]
# Cosine Similarity : 0.604577898979187
#
#
# Document: [1720]
# Cosine Similarity : 0.6045089960098267
#
#
# Document: [673]
# Cosine Similarity : 0.6044525504112244
#
#
# Document: [983]
# Cosine Similarity : 0.6044408082962036
#
#
# Document: [1617]
# Cosine Similarity : 0.6043607592582703
#
#
# Document: [1772]
# Cosine Similarity : 0.604284405708313
#
#
# Document: [1200]
# Cosine Similarity : 0.6042138934135437
#
#
# Document: [828]
# Cosine Similarity : 0.6042050123214722
#
#
# Document: [1399]
# Cosine Similarity : 0.6041461825370789
#
#
# Document: [309]
# Cosine Similarity : 0.6040586233139038
#
#
# Document: [925]
# Cosine Similarity : 0.6031602621078491
#
#
# Document: [1935]
# Cosine Similarity : 0.6030117273330688
#
#
# Document: [152]
# Cosine Similarity : 0.6030009388923645
#
#
# Document: [2145]
# Cosine Similarity : 0.6029825210571289
#
#
# Document: [224]
# Cosine Similarity : 0.6029425859451294
#
#
# Document: [1722]
# Cosine Similarity : 0.6028082966804504
#
#
# Document: [206]
# Cosine Similarity : 0.6026424169540405
#
#
# Document: [200]
# Cosine Similarity : 0.6024684906005859
#
#
# Document: [1739]
# Cosine Similarity : 0.6024458408355713
#
#
# Document: [1825]
# Cosine Similarity : 0.6024226546287537
#
#
# Document: [352]
# Cosine Similarity : 0.6023698449134827
#
#
# Document: [1431]
# Cosine Similarity : 0.6023467779159546
#
#
# Document: [495]
# Cosine Similarity : 0.6020102500915527
#
#
# Document: [526]
# Cosine Similarity : 0.6018739342689514
#
#
# Document: [1761]
# Cosine Similarity : 0.6018261909484863
#
#
# Document: [1169]
# Cosine Similarity : 0.6017811298370361
#
#
# Document: [60]
# Cosine Similarity : 0.6016628742218018
#
#
# Document: [833]
# Cosine Similarity : 0.6016441583633423
#
#
# Document: [330]
# Cosine Similarity : 0.6015018224716187
#
#
# Document: [1536]
# Cosine Similarity : 0.6013453006744385
#
#
# Document: [1148]
# Cosine Similarity : 0.6011987924575806
#
#
# Document: [1587]
# Cosine Similarity : 0.6007816791534424
#
#
# Document: [1425]
# Cosine Similarity : 0.6006860733032227
#
#
# Document: [1598]
# Cosine Similarity : 0.6006049513816833
#
#
# Document: [899]
# Cosine Similarity : 0.6005629301071167
#
#
# Document: [576]
# Cosine Similarity : 0.6005485653877258
#
#
# Document: [1141]
# Cosine Similarity : 0.6003323197364807
#
#
# Document: [2072]
# Cosine Similarity : 0.6000903844833374
#
#
# Document: [697]
# Cosine Similarity : 0.6000750064849854
#
#
# Document: [2118]
# Cosine Similarity : 0.5999884605407715
#
#
# Document: [197]
# Cosine Similarity : 0.5999522805213928
#
#
# Document: [534]
# Cosine Similarity : 0.5999180674552917
#
#
# Document: [1195]
# Cosine Similarity : 0.5998679995536804
#
#
# Document: [57]
# Cosine Similarity : 0.599690318107605
#
#
# Document: [97]
# Cosine Similarity : 0.5995834469795227
#
#
# Document: [1759]
# Cosine Similarity : 0.5992344617843628
#
#
# Document: [2032]
# Cosine Similarity : 0.5991925597190857
#
#
# Document: [1702]
# Cosine Similarity : 0.599075436592102
#
#
# Document: [1719]
# Cosine Similarity : 0.5990369319915771
#
#
# Document: [2040]
# Cosine Similarity : 0.5988287329673767
#
#
# Document: [501]
# Cosine Similarity : 0.5986512899398804
#
#
# Document: [2059]
# Cosine Similarity : 0.598633885383606
#
#
# Document: [1777]
# Cosine Similarity : 0.5981874465942383
#
#
# Document: [270]
# Cosine Similarity : 0.5981695055961609
#
#
# Document: [513]
# Cosine Similarity : 0.5978507995605469
#
#
# Document: [2142]
# Cosine Similarity : 0.5977185368537903
#
#
# Document: [51]
# Cosine Similarity : 0.5976506471633911
#
#
# Document: [424]
# Cosine Similarity : 0.5976492762565613
#
#
# Document: [546]
# Cosine Similarity : 0.5976439714431763
#
#
# Document: [1522]
# Cosine Similarity : 0.5975797176361084
#
#
# Document: [256]
# Cosine Similarity : 0.5973241329193115
#
#
# Document: [1015]
# Cosine Similarity : 0.5970454812049866
#
#
# Document: [1424]
# Cosine Similarity : 0.5968095064163208
#
#
# Document: [1133]
# Cosine Similarity : 0.5965680480003357
#
#
# Document: [1271]
# Cosine Similarity : 0.5964747667312622
#
#
# Document: [523]
# Cosine Similarity : 0.5964677333831787
#
#
# Document: [1355]
# Cosine Similarity : 0.5963726043701172
#
#
# Document: [872]
# Cosine Similarity : 0.5960296988487244
#
#
# Document: [2024]
# Cosine Similarity : 0.5958011746406555
#
#
# Document: [1968]
# Cosine Similarity : 0.595771312713623
#
#
# Document: [1995]
# Cosine Similarity : 0.5956481099128723
#
#
# Document: [752]
# Cosine Similarity : 0.5956164598464966
#
#
# Document: [2172]
# Cosine Similarity : 0.5954605937004089
#
#
# Document: [54]
# Cosine Similarity : 0.5954211354255676
#
#
# Document: [762]
# Cosine Similarity : 0.595409631729126
#
#
# Document: [1978]
# Cosine Similarity : 0.5953061580657959
#
#
# Document: [1824]
# Cosine Similarity : 0.595185399055481
#
#
# Document: [505]
# Cosine Similarity : 0.5948614478111267
#
#
# Document: [706]
# Cosine Similarity : 0.5947152972221375
#
#
# Document: [1909]
# Cosine Similarity : 0.5946959257125854
#
#
# Document: [960]
# Cosine Similarity : 0.5946786403656006
#
#
# Document: [1051]
# Cosine Similarity : 0.5945988297462463
#
#
# Document: [2018]
# Cosine Similarity : 0.594159722328186
#
#
# Document: [1760]
# Cosine Similarity : 0.5938653349876404
#
#
# Document: [2149]
# Cosine Similarity : 0.5938166379928589
#
#
# Document: [1161]
# Cosine Similarity : 0.5937596559524536
#
#
# Document: [2069]
# Cosine Similarity : 0.5936263799667358
#
#
# Document: [1014]
# Cosine Similarity : 0.5932358503341675
#
#
# Document: [1841]
# Cosine Similarity : 0.593177080154419
#
#
# Document: [1903]
# Cosine Similarity : 0.5929646492004395
#
#
# Document: [1847]
# Cosine Similarity : 0.592873752117157
#
#
# Document: [1496]
# Cosine Similarity : 0.5926843285560608
#
#
# Document: [1229]
# Cosine Similarity : 0.5917552709579468
#
#
# Document: [111]
# Cosine Similarity : 0.5911476612091064
#
#
# Document: [1572]
# Cosine Similarity : 0.5910931825637817
#
#
# Document: [625]
# Cosine Similarity : 0.5909864902496338
#
#
# Document: [1126]
# Cosine Similarity : 0.5909163355827332
#
#
# Document: [1385]
# Cosine Similarity : 0.5905141830444336
#
#
# Document: [1065]
# Cosine Similarity : 0.5904455184936523
#
#
# Document: [1636]
# Cosine Similarity : 0.5898864269256592
#
#
# Document: [165]
# Cosine Similarity : 0.589702844619751
#
#
# Document: [543]
# Cosine Similarity : 0.589702844619751
#
#
# Document: [1963]
# Cosine Similarity : 0.5893610715866089
#
#
# Document: [425]
# Cosine Similarity : 0.5892549157142639
#
#
# Document: [1901]
# Cosine Similarity : 0.5889108180999756
#
#
# Document: [2071]
# Cosine Similarity : 0.5888848304748535
#
#
# Document: [174]
# Cosine Similarity : 0.5886588096618652
#
#
# Document: [1280]
# Cosine Similarity : 0.5885709524154663
#
#
# Document: [1211]
# Cosine Similarity : 0.5885240435600281
#
#
# Document: [188]
# Cosine Similarity : 0.5885111093521118
#
#
# Document: [80]
# Cosine Similarity : 0.5884137749671936
#
#
# Document: [806]
# Cosine Similarity : 0.5883893370628357
#
#
# Document: [1778]
# Cosine Similarity : 0.5883607268333435
#
#
# Document: [1717]
# Cosine Similarity : 0.5879732966423035
#
#
# Document: [577]
# Cosine Similarity : 0.5877773761749268
#
#
# Document: [1187]
# Cosine Similarity : 0.5874539613723755
#
#
# Document: [981]
# Cosine Similarity : 0.5873273611068726
#
#
# Document: [1838]
# Cosine Similarity : 0.5866073966026306
#
#
# Document: [504]
# Cosine Similarity : 0.5865646600723267
#
#
# Document: [139]
# Cosine Similarity : 0.5858719944953918
#
#
# Document: [1017]
# Cosine Similarity : 0.5858590602874756
#
#
# Document: [1858]
# Cosine Similarity : 0.5856868028640747
#
#
# Document: [118]
# Cosine Similarity : 0.5853770971298218
#
#
# Document: [891]
# Cosine Similarity : 0.5852406024932861
#
#
# Document: [1035]
# Cosine Similarity : 0.5851738452911377
#
#
# Document: [175]
# Cosine Similarity : 0.5849740505218506
#
#
# Document: [940]
# Cosine Similarity : 0.5846661329269409
#
#
# Document: [1268]
# Cosine Similarity : 0.5845962166786194
#
#
# Document: [154]
# Cosine Similarity : 0.5845056176185608
#
#
# Document: [663]
# Cosine Similarity : 0.5844453573226929
#
#
# Document: [1339]
# Cosine Similarity : 0.5842679142951965
#
#
# Document: [1302]
# Cosine Similarity : 0.5842505097389221
#
#
# Document: [50]
# Cosine Similarity : 0.5837254524230957
#
#
# Document: [949]
# Cosine Similarity : 0.5832354426383972
#
#
# Document: [1661]
# Cosine Similarity : 0.5831202268600464
#
#
# Document: [177]
# Cosine Similarity : 0.582728385925293
#
#
# Document: [405]
# Cosine Similarity : 0.5826014280319214
#
#
# Document: [209]
# Cosine Similarity : 0.5820763111114502
#
#
# Document: [1921]
# Cosine Similarity : 0.5820486545562744
#
#
# Document: [442]
# Cosine Similarity : 0.5819528698921204
#
#
# Document: [433]
# Cosine Similarity : 0.5813502669334412
#
#
# Document: [297]
# Cosine Similarity : 0.5810892581939697
#
#
# Document: [1649]
# Cosine Similarity : 0.5808812379837036
#
#
# Document: [1405]
# Cosine Similarity : 0.5807095766067505
#
#
# Document: [1151]
# Cosine Similarity : 0.5806763172149658
#
#
# Document: [2106]
# Cosine Similarity : 0.5803225040435791
#
#
# Document: [751]
# Cosine Similarity : 0.5801495909690857
#
#
# Document: [1460]
# Cosine Similarity : 0.5801495909690857
#
#
# Document: [106]
# Cosine Similarity : 0.5799776315689087
#
#
# Document: [1989]
# Cosine Similarity : 0.5796863436698914
#
#
# Document: [1925]
# Cosine Similarity : 0.5796718001365662
#
#
# Document: [2148]
# Cosine Similarity : 0.5794742107391357
#
#
# Document: [2201]
# Cosine Similarity : 0.5791872143745422
#
#
# Document: [46]
# Cosine Similarity : 0.579168438911438
#
#
# Document: [1262]
# Cosine Similarity : 0.5788611769676208
#
#
# Document: [1045]
# Cosine Similarity : 0.5785083770751953
#
#
# Document: [1027]
# Cosine Similarity : 0.5780520439147949
#
#
# Document: [895]
# Cosine Similarity : 0.5775928497314453
#
#
# Document: [1560]
# Cosine Similarity : 0.5772802829742432
#
#
# Document: [942]
# Cosine Similarity : 0.5771270394325256
#
#
# Document: [1056]
# Cosine Similarity : 0.5769136548042297
#
#
# Document: [887]
# Cosine Similarity : 0.5768965482711792
#
#
# Document: [1286]
# Cosine Similarity : 0.5764974355697632
#
#
# Document: [1363]
# Cosine Similarity : 0.5764268636703491
#
#
# Document: [1928]
# Cosine Similarity : 0.5763524770736694
#
#
# Document: [1294]
# Cosine Similarity : 0.5763298869132996
#
#
# Document: [1808]
# Cosine Similarity : 0.5759323835372925
#
#
# Document: [261]
# Cosine Similarity : 0.5758556723594666
#
#
# Document: [428]
# Cosine Similarity : 0.5758472681045532
#
#
# Document: [2209]
# Cosine Similarity : 0.5758184790611267
#
#
# Document: [1291]
# Cosine Similarity : 0.5753400325775146
#
#
# Document: [1648]
# Cosine Similarity : 0.5747595429420471
#
#
# Document: [1432]
# Cosine Similarity : 0.5745515823364258
#
#
# Document: [2088]
# Cosine Similarity : 0.5743943452835083
#
#
# Document: [1238]
# Cosine Similarity : 0.5740485191345215
#
#
# Document: [658]
# Cosine Similarity : 0.5740454792976379
#
#
# Document: [1969]
# Cosine Similarity : 0.5737535953521729
#
#
# Document: [1384]
# Cosine Similarity : 0.5736338496208191
#
#
# Document: [244]
# Cosine Similarity : 0.5731609463691711
#
#
# Document: [75]
# Cosine Similarity : 0.5726426243782043
#
#
# Document: [665]
# Cosine Similarity : 0.5722672939300537
#
#
# Document: [584]
# Cosine Similarity : 0.5721433162689209
#
#
# Document: [1318]
# Cosine Similarity : 0.5721026659011841
#
#
# Document: [803]
# Cosine Similarity : 0.5721026659011841
#
#
# Document: [932]
# Cosine Similarity : 0.5704512596130371
#
#
# Document: [567]
# Cosine Similarity : 0.5702513456344604
#
#
# Document: [538]
# Cosine Similarity : 0.5700458288192749
#
#
# Document: [1186]
# Cosine Similarity : 0.570002555847168
#
#
# Document: [729]
# Cosine Similarity : 0.569635272026062
#
#
# Document: [519]
# Cosine Similarity : 0.5693615674972534
#
#
# Document: [1799]
# Cosine Similarity : 0.5693583488464355
#
#
# Document: [1985]
# Cosine Similarity : 0.568877100944519
#
#
# Document: [1607]
# Cosine Similarity : 0.5688128471374512
#
#
# Document: [1813]
# Cosine Similarity : 0.5687273144721985
#
#
# Document: [1185]
# Cosine Similarity : 0.5685432553291321
#
#
# Document: [1991]
# Cosine Similarity : 0.5683789253234863
#
#
# Document: [299]
# Cosine Similarity : 0.568364143371582
#
#
# Document: [1020]
# Cosine Similarity : 0.5683580636978149
#
#
# Document: [1095]
# Cosine Similarity : 0.5671709775924683
#
#
# Document: [2150]
# Cosine Similarity : 0.5668637156486511
#
#
# Document: [838]
# Cosine Similarity : 0.5668637156486511
#
#
# Document: [82]
# Cosine Similarity : 0.5668209791183472
#
#
# Document: [812]
# Cosine Similarity : 0.5667718052864075
#
#
# Document: [484]
# Cosine Similarity : 0.5666506290435791
#
#
# Document: [915]
# Cosine Similarity : 0.5664582848548889
#
#
# Document: [1094]
# Cosine Similarity : 0.5661709308624268
#
#
# Document: [398]
# Cosine Similarity : 0.5658338665962219
#
#
# Document: [1316]
# Cosine Similarity : 0.5657150745391846
#
#
# Document: [1430]
# Cosine Similarity : 0.5656030178070068
#
#
# Document: [146]
# Cosine Similarity : 0.5655159950256348
#
#
# Document: [1013]
# Cosine Similarity : 0.5648064613342285
#
#
# Document: [1524]
# Cosine Similarity : 0.564486026763916
#
#
# Document: [517]
# Cosine Similarity : 0.5644349455833435
#
#
# Document: [1177]
# Cosine Similarity : 0.564237654209137
#
#
# Document: [2110]
# Cosine Similarity : 0.563785970211029
#
#
# Document: [1162]
# Cosine Similarity : 0.5622446537017822
#
#
# Document: [2169]
# Cosine Similarity : 0.5622446537017822
#
#
# Document: [2138]
# Cosine Similarity : 0.5621505975723267
#
#
# Document: [255]
# Cosine Similarity : 0.5618653297424316
#
#
# Document: [1197]
# Cosine Similarity : 0.5614710450172424
#
#
# Document: [2146]
# Cosine Similarity : 0.5614666938781738
#
#
# Document: [1763]
# Cosine Similarity : 0.5612783432006836
#
#
# Document: [1660]
# Cosine Similarity : 0.5608371496200562
#
#
# Document: [38]
# Cosine Similarity : 0.5608371496200562
#
#
# Document: [1585]
# Cosine Similarity : 0.5606362223625183
#
#
# Document: [1977]
# Cosine Similarity : 0.5605952143669128
#
#
# Document: [1220]
# Cosine Similarity : 0.5604194402694702
#
#
# Document: [2224]
# Cosine Similarity : 0.5602291226387024
#
#
# Document: [127]
# Cosine Similarity : 0.5598341226577759
#
#
# Document: [87]
# Cosine Similarity : 0.5597468614578247
#
#
# Document: [1883]
# Cosine Similarity : 0.5596766471862793
#
#
# Document: [723]
# Cosine Similarity : 0.5592859983444214
#
#
# Document: [1658]
# Cosine Similarity : 0.5590987205505371
#
#
# Document: [2223]
# Cosine Similarity : 0.5582988262176514
#
#
# Document: [436]
# Cosine Similarity : 0.55762779712677
#
#
# Document: [1606]
# Cosine Similarity : 0.5565497279167175
#
#
# Document: [171]
# Cosine Similarity : 0.5551643967628479
#
#
# Document: [754]
# Cosine Similarity : 0.5543813705444336
#
#
# Document: [1616]
# Cosine Similarity : 0.5543133020401001
#
#
# Document: [1312]
# Cosine Similarity : 0.5534164905548096
#
#
# Document: [898]
# Cosine Similarity : 0.5533177852630615
#
#
# Document: [1768]
# Cosine Similarity : 0.550936222076416
#
#
# Document: [587]
# Cosine Similarity : 0.5499266386032104
#
#
# Document: [2111]
# Cosine Similarity : 0.5482711791992188
#
#
# Document: [645]
# Cosine Similarity : 0.5478459596633911
#
#
# Document: [1860]
# Cosine Similarity : 0.5470983386039734
#
#
# Document: [1721]
# Cosine Similarity : 0.543468177318573
#
#
# Document: [1629]
# Cosine Similarity : 0.5430914759635925
#
#
# Document: [1855]
# Cosine Similarity : 0.5429219603538513
#
#
# Document: [965]
# Cosine Similarity : 0.5428482294082642
#
#
# Document: [1608]
# Cosine Similarity : 0.5418066382408142
#
#
# Document: [421]
# Cosine Similarity : 0.5408646464347839
#
#
# Document: [2127]
# Cosine Similarity : 0.5399053692817688
#
#
# Document: [1994]
# Cosine Similarity : 0.5365152359008789
#
#
# Document: [1523]
# Cosine Similarity : 0.5360337495803833
#
#
# Document: [1730]
# Cosine Similarity : 0.5331832766532898
#
#
# Document: [2162]
# Cosine Similarity : 0.5328482389450073
#
#
# Document: [830]
# Cosine Similarity : 0.5324665307998657
#
#
# Document: [223]
# Cosine Similarity : 0.5315459966659546
#
#
# Document: [1248]
# Cosine Similarity : 0.5307527780532837
#
#
# Document: [1584]
# Cosine Similarity : 0.5289299488067627
#
#
# Document: [1319]
# Cosine Similarity : 0.5198042392730713
#
#
# Document: [1428]
# Cosine Similarity : 0.5194414258003235
#
#
# Document: [996]
# Cosine Similarity : 0.5129544734954834
#
#
# Document: [876]
# Cosine Similarity : 0.5007770657539368
#
#
# Document: [2045]
# Cosine Similarity : 0.49168604612350464
#
#
# Document: [1711]
# Cosine Similarity : 0.49127197265625

# %% [markdown]
# Bag of Words TF-IDF

# %%
choice = int(input("Choose: \n 1. Bag of Words \n 2. TF-IDF \n"))
if choice == 1:
  cv=CountVectorizer(max_features=5000)
  X=cv.fit_transform(news_df.Article).toarray()
  y=np.array(news_df['Category'].values)
elif choice == 2:
  tf_idf=TfidfVectorizer()
  X=tf_idf.fit_transform(news_df.Article).toarray()
  y=np.array(news_df['Category'].values)
else:
  print('wrong input')
# Out:
# Choose:
#  1. Bag of Words
#  2. TF-IDF
# 2

# %% [markdown]
# Train Test Split

# %%
len(X[0])
# Out:
# 17096

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,shuffle=True,stratify=y,random_state=42)

print("Shape of train data is: ",X_train.shape)
print("Shape of test data is: ",X_test.shape)
# Out:
# Shape of train data is:  (636, 5000)
# Shape of test data is:  (273, 5000)

# %% [markdown]
# ## Naive Bayes Classifier

# %%
nb=MultinomialNB()
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nb_train=accuracy_score(y_train,nb.predict(X_train))
nb_test=accuracy_score(y_test,nb.predict(X_test))
print("Training accuracy: ",nb_train.round(3))
print("Testing accuracy: ",nb_test.round(3))
# Out:
# Training accuracy:  0.988
# Testing accuracy:  0.97

# %%
#Making Prediction and computing ROC-AUC score
y_pred_NB=nb.predict(X_test)
y_pred_proba=nb.predict_proba(X_test)
rocauc_score= roc_auc_score(y_test,y_pred_proba,multi_class="ovr")
print("ROC AUC score: ",rocauc_score.round(3))
# Out:
# ROC AUC score:  0.999

# %%
precision=precision_score(y_test,y_pred_NB,average='weighted')
recall=recall_score(y_test,y_pred_NB,average='weighted')
f1=f1_score(y_test,y_pred_NB,average='weighted')
print("Precision score: ",precision.round(3))
print("Recall score: ",recall.round(3))
print("f1 score: ",f1.round(3))
# Out:
# Precision score:  0.971
# Recall score:  0.97
# f1 score:  0.97

# %% [markdown]
# Confusion Matrix

# %%
confusion=confusion_matrix(y_test,y_pred_NB)
plt.figure(figsize=(10,5))
sns.heatmap(confusion,annot=True,fmt='d',cbar=False,cmap='Blues')
plt.xlabel("Predicted label")
plt.ylabel("Actual label")
plt.show()

# %%
print(classification_report(y_test,y_pred_NB))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      0.99      0.98       120
#            2       0.97      0.97      0.97       153
#            3       0.99      1.00      0.99       154
#            4       1.00      0.91      0.95       116
#            5       0.94      0.97      0.95       125
#
#     accuracy                           0.97       668
#    macro avg       0.97      0.97      0.97       668
# weighted avg       0.97      0.97      0.97       668

# %% [markdown]
# ## **Generalised function for model**

# %% [markdown]
# Model training

# %%
def model_training(model,X_train,X_test,y_train):
  model.fit(X_train,y_train)
  y_pred=model.predict(X_test)
  y_pred_proba=model.predict_proba(X_test)
  return y_pred,y_pred_proba

# %% [markdown]
# Model Evaluation

# %%
def evaluate_model(model,y_pred,y_pred_proba,X_train,X_test,y_train,y_test):

  #Calculating train and test accuracy
  train_acc=accuracy_score(y_train,model.predict(X_train))
  test_acc=accuracy_score(y_test,model.predict(X_test))
  print("Training accuracy: ",train_acc.round(3))
  print("Testing accuracy: ",test_acc.round(3))

  #computing ROC AUC score
  rocauc_score= roc_auc_score(y_test,y_pred_proba,multi_class="ovr")
  print("ROC AUC score: ",rocauc_score.round(3))

  #calculating precision,recall,f1score
  precision=precision_score(y_test,y_pred,average='weighted')
  recall=recall_score(y_test,y_pred,average='weighted')
  f1=f1_score(y_test,y_pred,average='weighted')
  print("Precision score: ",precision.round(3))
  print("Recall score: ",recall.round(3))
  print("f1 score: ",f1.round(3))
  print()

# %% [markdown]
# Decision Tree Classifier

# %%
dt=DecisionTreeClassifier()

#model training
y_pred_dt,y_pred_proba_dt=model_training(dt)

#model evaluation
evaluate_model(dt,y_pred_dt,y_pred_proba_dt)
# Out:
# Training accuracy:  1.0
# Testing accuracy:  0.847
# ROC AUC score:  0.901
# Precision score:  0.851
# Recall score:  0.847
# f1 score:  0.847

# %% [markdown]
# K Nearest Neighbours Classifier

# %%
knn=KNeighborsClassifier(n_neighbors=5)

#model training
y_pred_knn,y_pred_proba_knn=model_training(knn)

#model evaluation
evaluate_model(knn,y_pred_knn,y_pred_proba_knn)
# Out:
# Training accuracy:  0.963
# Testing accuracy:  0.931
# ROC AUC score:  0.989
# Precision score:  0.933
# Recall score:  0.931
# f1 score:  0.931

# %% [markdown]
# Random Forest Classifier

# %%
rf=RandomForestClassifier()

#model training
y_pred_rf,y_pred_proba_rf=model_training(rf)

#model evaluation
evaluate_model(rf,y_pred_rf,y_pred_proba_rf)
# Out:
# Training accuracy:  1.0
# Testing accuracy:  0.972
# ROC AUC score:  0.997
# Precision score:  0.972
# Recall score:  0.972
# f1 score:  0.972

# %% [markdown]
# ***From the above 4 models tested, Naive Bayes Classifier seems to be the best performing model. It provides better training and testing accuracy as well as excellent scores for precision, recall and f1 score.***
